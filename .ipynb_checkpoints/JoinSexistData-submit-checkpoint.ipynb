# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('corpus_SexistContent.csv', sep='\t', header=None)
#         .drop(0, axis=1)\
#         .rename(columns={1: 'id'})
# no header to data
df1.head()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                     0  1
# 0  327031890622164993  0
# 1  330425562201993216  0
# 2  326796299179548672  0
# 3  334548844731826176  0
# 4  332500824150392833  0

# %%
df1.columns=['id', 'label']
df1.head()
# Out:
#                    id  label
# 0  327031890622164993      0
# 1  330425562201993216      0
# 2  326796299179548672      0
# 3  334548844731826176      0
# 4  332500824150392833      0

# %%
df2 = df2[['id', 'text']].copy()

# %%
df2.head()
# Out:
#                    id                                               text
# 0  276070435551068160  @SnappyRockJr Il fais un putain de match mec, ...
# 1  276070936040574977  @SnappyRockJr Mec Menez est trop bon, regarde ...
# 2         10162393410  JP Huchon imite PÃ©cresse: pas une bonne idÃ©e...
# 3  272819573848432640  @Amkhatmi @annagueye oui. .mais Ã  droite il n...
# 4  272016322022494208  @CentreHubertine @iledefrance au QuÃ©bec oÃ¹ j...

# %%
dfnew=df1.merge(df2, how='inner', on='id')

# %%
dfnew.head()
# Out:
#                    id  label  \
# 0  950792636335616000      0
#
#                                                 text
# 0  Une centaine de femmes franÃ§aises dÃ©noncent ...

# %%
list1 = df1['id'].values

# %%
list2 = df2['id'].values

# %%
for id1 in list1:
    if id1 in list2:
        print(id1)
# Out:
# 950792636335616000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12274 entries, 0 to 12273
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      12274 non-null  int64
#  1   label   12274 non-null  int64
# dtypes: int64(2)
# memory usage: 191.9 KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67385 entries, 0 to 67384
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      67385 non-null  int64
#  1   text    67385 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.0+ MB

# %%
print(type(df1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Split string column into two new columns
df1[['id', 'label']] = df1.id.str.split("\t", expand = True)
print(df1)
# Out:
#                        id label
# 0      327031890622164993     0
# 1      330425562201993216     0
# 2      326796299179548672     0
# 3      334548844731826176     0
# 4      332500824150392833     0
# ...                   ...   ...
# 12269  991769637506486274     1
# 12270  991930025955004416     1
# 12271  991937217789681664     1
# 12272  991948109910507520     1
# 12273  992014962582327296     1
#
# [12274 rows x 2 columns]

# %%
df1.to_csv('SexistColumns.csv')
# export dataframe to new csv file

# %%
df3 = pd.read_csv('SexistColumns.csv')
df3
# Out:
#        Unnamed: 0                  id  label
# 0               0  327031890622164993      0
# 1               1  330425562201993216      0
# 2               2  326796299179548672      0
# 3               3  334548844731826176      0
# 4               4  332500824150392833      0
# ...           ...                 ...    ...
# 12269       12269  991769637506486274      1
# 12270       12270  991930025955004416      1
# 12271       12271  991937217789681664      1
# 12272       12272  991948109910507520      1
# 12273       12273  992014962582327296      1
#
# [12274 rows x 3 columns]

# %%
df4 = pd.merge(df2, df3)
df4
# Out:
#   coordinates                      created_at                 hashtags media  \
# 0         NaN  Tue Jan 09 18:13:24 +0000 2018  BalanceTonPorc MoiAussi   NaN
#
#                     urls  favorite_count                  id  \
# 0  http://bit.ly/2CV0ELD              14  950792636335616000
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_user_id  ...  \
# 0                     NaN                    NaN                  NaN  ...
#
#   user_listed_count               user_location  user_name  user_screen_name  \
# 0              3654  MontrÃ©al, QuÃ©bec, Canada  Le Devoir          LeDevoir
#
#    user_statuses_count  user_time_zone                user_urls user_verified  \
# 0               166143             NaN  http://www.ledevoir.com          True
#
#   Unnamed: 0 label
# 0        545     0
#
# [1 rows x 37 columns]

# %%
df5 = df4.drop(df4.iloc[:, 2:33], inplace=True, axis=1)
df5

# %%
print(df5)
# Out:
# None

# %%
df4 = pd.merge(df2, df3).drop(['coordinates', 'created_at', 'hashtags', 'urls', 'favorite_count', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_user_id', 'lang', 'user_listed_count', 'user_name', 'user_screen_name', 'user_statuses_count', 'user_time_zone', 'user_urls', 'user_verified', 'place', 'media', 'possibly_sensitive', 'quote_id', 'retweet_count', 'retweet_id', 'retweet_screen_name', 'source', 'user_created_at', 'user_id', 'user_default_profile_image', 'user_description', 'user_favourites_count', 'user_followers_count', 'user_friends_count'], axis=1)
df4
# Out:
#                    id                                               text  \
# 0  950792636335616000  Une centaine de femmes franÃ§aises dÃ©noncent ...
#
#                                            tweet_url  \
# 0  https://twitter.com/LeDevoir/status/9507926363...
#
#                 user_location  Unnamed: 0  label
# 0  MontrÃ©al, QuÃ©bec, Canada         545      0

# %%
df4 = pd.merge(df2, df3)
df4
# Out:
#   coordinates                      created_at                 hashtags media  \
# 0         NaN  Tue Jan 09 18:13:24 +0000 2018  BalanceTonPorc MoiAussi   NaN
#
#                     urls  favorite_count                  id  \
# 0  http://bit.ly/2CV0ELD              14  950792636335616000
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_user_id  ...  \
# 0                     NaN                    NaN                  NaN  ...
#
#   user_listed_count               user_location  user_name  user_screen_name  \
# 0              3654  MontrÃ©al, QuÃ©bec, Canada  Le Devoir          LeDevoir
#
#    user_statuses_count  user_time_zone                user_urls user_verified  \
# 0               166143             NaN  http://www.ledevoir.com          True
#
#   Unnamed: 0 label
# 0        545     0
#
# [1 rows x 37 columns]

# %%
df4.to_csv('hydratedSexist.csv')
# export dataframe to new csv file

# %%
df4 = pd.merge(df2, df3).drop(df.iloc[:, 2:33], inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mc/1k6qg5js1x31mqzdq17v2yym0000gn/T/ipykernel_27356/1687637344.py in <module>
# ----> 1 df4 = pd.merge(df2, df3).drop(df.iloc[:, 2:33], inplace=True, axis=1)
#
# NameError: name 'df' is not defined

# %%
df5 = pd.merge(df2, df3, left_on="id", right_on="label").drop('Unnamed: 0', axis=1)
df5
# Out:
# Empty DataFrame
# Columns: [coordinates, created_at, hashtags, media, urls, favorite_count, id_x, in_reply_to_screen_name, in_reply_to_status_id, in_reply_to_user_id, lang, place, possibly_sensitive, quote_id, retweet_count, retweet_id, retweet_screen_name, source, text, tweet_url, user_created_at, user_id, user_default_profile_image, user_description, user_favourites_count, user_followers_count, user_friends_count, user_listed_count, user_location, user_name, user_screen_name, user_statuses_count, user_time_zone, user_urls, user_verified, id_y, label]
# Index: []
#
# [0 rows x 37 columns]

# %%
dffinal = pd.read_csv('SexistColumns.csv', header=None)

# %%
dffinal.head()
# Out:
#      0                   1      2
# 0  NaN                  id  label
# 1  0.0  327031890622164993      0
# 2  1.0  330425562201993216      0
# 3  2.0  326796299179548672      0
# 4  3.0  334548844731826176      0

# %%
dffinal.drop(dffinal.columns[[0, 2]], axis=1, inplace=True)
dffinal.head()
# Out:
#                     1
# 0                  id
# 1  327031890622164993
# 2  330425562201993216
# 3  326796299179548672
# 4  334548844731826176

# %%
dffinal.to_csv('SexistIDs.csv', header=False, index=False)
# https://sparkbyexamples.com/pandas/pandas-to-csv-no-index/#:~:text=In%20order%20to%20export%20pandas,param%20on%20to_csv()%20method.
# without index & header

# %%
dfid = pd.read_csv('SexistIDs.csv', header=None)
dfid.head()
# Out:
#                     0
# 0                  id
# 1  327031890622164993
# 2  330425562201993216
# 3  326796299179548672
# 4  334548844731826176

# %%
dfpls.rename(columns={"id": "label"})
dfpls.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
dfb = pd.read_csv('Sexisthydrated.csv')
dfb.head()
# Out:
#   coordinates                      created_at  \
# 0         NaN  Wed Apr 24 12:10:53 +0000 2013
# 1         NaN  Tue Feb 20 18:32:20 +0000 2018
# 2         NaN  Thu Oct 05 13:16:30 +0000 2017
# 3         NaN  Sun Jan 21 10:02:03 +0000 2018
# 4         NaN  Mon Jan 22 09:10:55 +0000 2018
#
#                                             hashtags  \
# 0                                             ironie
# 1                                           Wauquiez
# 2                                                NaN
# 3  sexisme clichés Egalité AccordEgalitéProfessio...
# 4                                                NaN
#
#                                                media  \
# 0                                                NaN
# 1  https://twitter.com/pierre_cuny/status/9660176...
# 2  https://twitter.com/franceinfo/status/91592868...
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
listb = dfb['id'].values

# %%
for id1 in list1:
    if id1 in listb:
        print(id1)
# Out:
# 327031890622164993
# 326796299179548672
# 334548844731826176
# 334424362033762304
# 421708259716636672
# 420942263154249728
# 707088385995890689
# 955356819324657665
# 955363354083766272
# 955408486153715713
# 955367160334946305
# 955357419147878400
# 955380056024649728
# 955364522268741632
# 954868960905834501
# 955000687162781696
# 954995897087287297
# 955017638438109184
# 938206714175873024
# 938175951787249666
# 938389967486836736
# 938182679085961216
# 938388997709221890
# 986489352514691072
# 986516637728813056
# 986626598748262400
# 915928687589150722
# 916212409748115458
# 916324223194488832
# 918515284725596161
# 916234131352244224
# 917344171865837568
# 915956748929945601
# 958054639764520960
# 958056037227073537
# 950463901015183360
# 500558476234743809
# 492372887484239873
# 492263999615295488
# 508357259207143424
# 491623617839759360
# 953557720774397954
# 938803565702926336
# 938775894457507840
# 938798772657836038
# 942465916356448256
# 954468585103134720
# ...

# %%
dfhydrated=df1.merge(dfb, how='inner', on='id')
dfhydrated.head()
# Out:
#                    id  label coordinates                      created_at  \
# 0  327031890622164993      0         NaN  Wed Apr 24 12:10:53 +0000 2013
# 1  326796299179548672      0         NaN  Tue Apr 23 20:34:43 +0000 2013
# 2  334548844731826176      0         NaN  Wed May 15 06:00:34 +0000 2013
# 3  334424362033762304      0         NaN  Tue May 14 21:45:55 +0000 2013
# 4  421708259716636672      0         NaN  Fri Jan 10 18:20:58 +0000 2014
#
#                                             hashtags media  \
# 0                                             ironie   NaN
# 1                                             Ironie   NaN
# 2                            femmes politique ironie   NaN
# 3                                             Ironie   NaN
# 4  payetashnek tentativedeseductionenmilieuurbain...   NaN
#
#                      urls  favorite_count in_reply_to_screen_name  \
# 0                     NaN               0                     NaN
# ...

# %%
dfhydrated = dfhydrated[['id', 'text', 'label']].copy()
dfhydrated.head()
# Out:
#                    id                                               text  \
# 0  327031890622164993  @MirkoPlsll @IanisRondeau ouais.. un chef d'oe...
# 1  326796299179548672        @MamzelleMNa Une très humble femme! #Ironie
# 2  334548844731826176  BLOGUE - «Tsé, la parité homme-femme...» au se...
# 3  334424362033762304  Je suis une femme matérialiste et superficiell...
# 4  421708259716636672  Mise en ligne de mon article sur @PayeTaShnek ...
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
dfhydrated.to_csv('sexistinfo.csv', index=False)

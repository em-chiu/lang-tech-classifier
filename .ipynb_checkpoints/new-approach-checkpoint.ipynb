# %% [markdown]
# <a href="https://colab.research.google.com/github/em-chiu/intersection_project/blob/main/EC%20Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import urllib.request
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk import word_tokenize
import re
import numpy as np
from collections import Counter
from sklearn import preprocessing
import string
nltk.download('averaged_perceptron_tagger') # to solve pos feature extract issue
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score

import pandas as pd # data processing
import csv
from bs4 import BeautifulSoup
import sys
import unidecode
import seaborn as sns
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/emilychiu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/emilychiu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/emilychiu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# import os
# data_dir = '../data/'
# or_fname = 'FTR_new_labels.csv'
# fname = data_dir+or_fname


# load the data to df, try1 works
df = pd.read_csv('FTR_labels_copy.csv', header=None, encoding = "ISO-8859-1")\
        .drop(0, axis=1)\
        .rename(columns={1: 'tweet'})

# %%
# preview data
df.head()
# Out:
#                                                tweet      2
# 0                                              tweet  label
# 1  Elle ne devait pas dÃ©gager la nazi ??? https:...      1
# 2  je dois faire un oral en anglais sur Hitler et...      0
# 3  @ambrassmoi_ A Ã§a ð¤ de ressembler Ã  la cr...      0
# 4  "Par curiositÃ©, jâai voulu Ã©couter les dis...      0

# %%
# Drop first row 
# by selecting all rows from first row onwards
df = df.iloc[1: , :]

# %%
# view dimensions of dataset
df.shape
# 2857 instances and 2 attributes in dataset
# Out:
# (2856, 2)

# %%
# Rename column names
col_names = ['tweet', 'label']
df.columns = col_names
df.columns
# Out:
# Index(['tweet', 'label'], dtype='object')

# %%
# preview after renaming
df.head()
# Out:
#                                                tweet label
# 1  Elle ne devait pas dÃ©gager la nazi ??? https:...     1
# 2  je dois faire un oral en anglais sur Hitler et...     0
# 3  @ambrassmoi_ A Ã§a ð¤ de ressembler Ã  la cr...     0
# 4  "Par curiositÃ©, jâai voulu Ã©couter les dis...     0
# 5  @tical10 @ExBarcaFan74523 @ConflitsFrance Mdr ...     1

# %%
# summary of data
df.info()
# no missing data
# Categorical variables have data type object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2856 entries, 1 to 2856
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tweet   2856 non-null   object
#  1   label   2856 non-null   object
# dtypes: object(2)
# memory usage: 44.8+ KB

# %%
# find categorical variables
categorical = [var for var in df.columns if df[var].dtype=='O']

print('There are {} categorical variables\n'.format(len(categorical)))

print('The categorical variables are :\n\n', categorical)
# Out:
# There are 2 categorical variables
#
# The categorical variables are :
#
#  ['tweet', 'label']

# %%
# view the categorical variables
df[categorical].head()
# Out:
#                                                tweet label
# 1  Elle ne devait pas dÃ©gager la nazi ??? https:...     1
# 2  je dois faire un oral en anglais sur Hitler et...     0
# 3  @ambrassmoi_ A Ã§a ð¤ de ressembler Ã  la cr...     0
# 4  "Par curiositÃ©, jâai voulu Ã©couter les dis...     0
# 5  @tical10 @ExBarcaFan74523 @ConflitsFrance Mdr ...     1

# %%
# check missing values in categorical variables
df[categorical].isnull().sum()
# Out:
# tweet    0
# label    0
# dtype: int64

# %%
# view frequency counts of values in categorical variables
for var in categorical: 
    print(df[var].value_counts())

# 0        1929
# 1         927
# Out:
# "0. Moi\n                                                                                                                                                    4
# @flo__lfc @leo2saucisson @ActuFoot_ CrÃ¨ve                                                                                                                   2
# "ððððð\n                                                                                                                                      2
# """A Bright Room Called Day"", la cinglante leÃ§on d'histoire de Tony Kushner. Ma critique dans Les SoirÃ©es de Paris â¶ï¸Â https://t.co/Ydl1PqJv7AÂ \n    2
# "En ce moment sur LFM #CrÃ¨ve-cÅur#Mauvais Åil et toujours Le Morning sur LFM de 07h Ã  10h du Lundi au Vendredi.\n                                        2
#                                                                                                                                                             ..
# de toutes faÃ§ons, c'est une mascarade. personne n'est mort et le masque sert Ã  rien #nazi #GiletsJaunes                                                    1
# Ah je crÃ¨ve de froid                                                                                                                                        1
# @Weatherboy_fr @ButchCoolidge11 @DamienRieu Bah oui câest les franÃ§ais qui ont Ã©lus hitler câest connuâ¦ gÃ©nie !                                     1
# @mormach Pitoyable cette information dirigÃ©e !!! On en crÃ¨ve !!!                                                                                           1
# Sal Noir https://t.co/9Sr7f4Mzr5 https://t.co/53F9rBpJsf                                                                                                     1
# Name: tweet, Length: 2847, dtype: int64
# 0    1929
# 1     927
# Name: label, dtype: int64

# %%
# view frequency distribution of categorical variables
for var in categorical:   
    print(df[var].value_counts()/float(len(df)))
# Out:
# "0. Moi\n                                                                                                                                                    0.001401
# @flo__lfc @leo2saucisson @ActuFoot_ CrÃ¨ve                                                                                                                   0.000700
# "ððððð\n                                                                                                                                      0.000700
# """A Bright Room Called Day"", la cinglante leÃ§on d'histoire de Tony Kushner. Ma critique dans Les SoirÃ©es de Paris â¶ï¸Â https://t.co/Ydl1PqJv7AÂ \n    0.000700
# "En ce moment sur LFM #CrÃ¨ve-cÅur#Mauvais Åil et toujours Le Morning sur LFM de 07h Ã  10h du Lundi au Vendredi.\n                                        0.000700
#                                                                                                                                                                ...
# de toutes faÃ§ons, c'est une mascarade. personne n'est mort et le masque sert Ã  rien #nazi #GiletsJaunes                                                    0.000350
# Ah je crÃ¨ve de froid                                                                                                                                        0.000350
# @Weatherboy_fr @ButchCoolidge11 @DamienRieu Bah oui câest les franÃ§ais qui ont Ã©lus hitler câest connuâ¦ gÃ©nie !                                     0.000350
# @mormach Pitoyable cette information dirigÃ©e !!! On en crÃ¨ve !!!                                                                                           0.000350
# Sal Noir https://t.co/9Sr7f4Mzr5 https://t.co/53F9rBpJsf                                                                                                     0.000350
# Name: tweet, Length: 2847, dtype: float64
# 0    0.67542
# 1    0.32458
# Name: label, dtype: float64

# %%
# # check frequency distribution of values in label variable
df.label.value_counts()
# Out:
# 0    1929
# 1     927
# Name: label, dtype: int64

# %%
# Lowercase all words
def make_lower(a_string):
    return a_string.lower()

df['lowered_tweet'] = df['tweet'].apply(make_lower)
df['lowered_tweet']
# Out:
# 1       elle ne devait pas dã©gager la nazi ??? https:...
# 2       je dois faire un oral en anglais sur hitler et...
# 3       @ambrassmoi_ a ã§a ð¤ de ressembler ã  la cr...
# 4       "par curiositã©, jâai voulu ã©couter les dis...
# 5       @tical10 @exbarcafan74523 @conflitsfrance mdr ...
#                               ...
# 2852                           kevin câest un sal noir.
# 2853    bougnoule bamboula sale arabe , elle est belle...
# 2854      @b_mahrezz tu viens de le traiter de sal noir ?
# 2855                     sal noir https://t.co/jraabftel8
# 2856    sal noir https://t.co/9sr7f4mzr5 https://t.co/...
# Name: lowered_tweet, Length: 2856, dtype: object

# %%
# Remove all punctuation
def remove_punctuation(a_string):    
    a_string = re.sub(r'[^\w\s]','',a_string)
    return a_string

df['remove_punctuation'] = df['lowered_tweet'].apply(remove_punctuation)
df['remove_punctuation']

# do I want to remove puncutation???
# Out:
# 1       elle ne devait pas dãgager la nazi  httpstcona...
# 2       je dois faire un oral en anglais sur hitler et...
# 3       ambrassmoi_ a ãa ð de ressembler ã  la croix n...
# 4       par curiositã jâai voulu ãcouter les discours ...
# 5       tical10 exbarcafan74523 conflitsfrance mdr deu...
#                               ...
# 2852                              kevin câest un sal noir
# 2853    bougnoule bamboula sale arabe  elle est belle ...
# 2854        b_mahrezz tu viens de le traiter de sal noir
# 2855                          sal noir httpstcojraabftel8
# 2856       sal noir httpstco9sr7f4mzr5 httpstco53f9rbpjsf
# Name: remove_punctuation, Length: 2856, dtype: object

# %%
tokenizer = nltk.TweetTokenizer()
# keeps hashtags together, subset of word_tokenize

df['tokenized_tweet'] = df['lowered_tweet'].apply(tokenizer.tokenize)
df.head()

# https://stackoverflow.com/questions/48363461/passing-a-pandas-dataframe-column-to-an-nltk-tokenizer
#df['tweet'] = df['tweet'].apply(nltk.TweetTokenizer)
# this overwrote what i did
# Out:
#                                                tweet label  \
# 1  Elle ne devait pas dÃ©gager la nazi ??? https:...     1
# 2  je dois faire un oral en anglais sur Hitler et...     0
# 3  @ambrassmoi_ A Ã§a ð¤ de ressembler Ã  la cr...     0
# 4  "Par curiositÃ©, jâai voulu Ã©couter les dis...     0
# 5  @tical10 @ExBarcaFan74523 @ConflitsFrance Mdr ...     1
#
#                                      tokenized_tweet  \
# 1  [elle, ne, devait, pas, dã, ©, gager, la, nazi...
# 2  [je, dois, faire, un, oral, en, anglais, sur, ...
# 3  [@ambrassmoi_, a, ã, §, a, ð, , ¤, , de, res...
# 4  [", par, curiositã, ©, ,, jâ, , , ai, voulu,...
# 5  [@tical10, @exbarcafan74523, @conflitsfrance, ...
#
#                                        lowered_tweet
# 1  elle ne devait pas dã©gager la nazi ??? https:...
# 2  je dois faire un oral en anglais sur hitler et...
# 3  @ambrassmoi_ a ã§a ð¤ de ressembler ã  la cr...
# 4  "par curiositã©, jâai voulu ã©couter les dis...
# 5  @tical10 @exbarcafan74523 @conflitsfrance mdr ...

# %%
df['tweet'] = df['tweet'].astype(pd.StringDtype())
df['tweet']
# must feed str into vectorizer
# Out:
# 1       <nltk.tokenize.casual.TweetTokenizer object at...
# 2       <nltk.tokenize.casual.TweetTokenizer object at...
# 3       <nltk.tokenize.casual.TweetTokenizer object at...
# 4       <nltk.tokenize.casual.TweetTokenizer object at...
# 5       <nltk.tokenize.casual.TweetTokenizer object at...
#                               ...
# 2852    <nltk.tokenize.casual.TweetTokenizer object at...
# 2853    <nltk.tokenize.casual.TweetTokenizer object at...
# 2854    <nltk.tokenize.casual.TweetTokenizer object at...
# 2855    <nltk.tokenize.casual.TweetTokenizer object at...
# 2856    <nltk.tokenize.casual.TweetTokenizer object at...
# Name: tweet, Length: 2856, dtype: string

# %%
def generate_stopwords():
    stopwords_en = nltk.corpus.stopwords.words("english")
    stopwords_fr = nltk.corpus.stopwords.words("french")
    stop_words = stopwords_en+stopwords_fr
    other_exclusions = ["les"]
    stop_words.extend(other_exclusions)
    return stop_words

def remove_stopwords(text_list, sw):
    return [word for word in text_list if word not in sw]

# %%
allstopwords = generate_stopwords()
allstopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'au',
#  'aux',
#  'avec',
#  'ce',
#  'ces',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'et',
#  'eux',
#  'il',
#  'ils',
#  'je',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'ma',
#  'mais',
#  'me',
#  'même',
#  'mes',
#  'moi',
#  'mon',
#  'ne',
#  'nos',
#  'notre',
#  'nous',
#  'on',
#  'ou',
#  'par',
#  'pas',
#  'pour',
#  'qu',
#  'que',
#  'qui',
#  'sa',
#  'se',
#  'ses',
#  'son',
#  'sur',
#  'ta',
#  'te',
#  'tes',
#  'toi',
#  'ton',
#  'tu',
#  'un',
#  'une',
#  'vos',
#  'votre',
#  'vous',
#  'c',
#  'd',
#  'j',
#  'l',
#  'à',
#  'm',
#  'n',
#  's',
#  't',
#  'y',
#  'été',
#  'étée',
#  'étées',
#  'étés',
#  'étant',
#  'étante',
#  'étants',
#  'étantes',
#  'suis',
#  'es',
#  'est',
#  'sommes',
#  'êtes',
#  'sont',
#  'serai',
#  'seras',
#  'sera',
#  'serons',
#  'serez',
#  'seront',
#  'serais',
#  'serait',
#  'serions',
#  'seriez',
#  'seraient',
#  'étais',
#  'était',
#  'étions',
#  'étiez',
#  'étaient',
#  'fus',
#  'fut',
#  'fûmes',
#  'fûtes',
#  'furent',
#  'sois',
#  'soit',
#  'soyons',
#  'soyez',
#  'soient',
#  'fusse',
#  'fusses',
#  'fût',
#  'fussions',
#  'fussiez',
#  'fussent',
#  'ayant',
#  'ayante',
#  'ayantes',
#  'ayants',
#  'eu',
#  'eue',
#  'eues',
#  'eus',
#  'ai',
#  'as',
#  'avons',
#  'avez',
#  'ont',
#  'aurai',
#  'auras',
#  'aura',
#  'aurons',
#  'aurez',
#  'auront',
#  'aurais',
#  'aurait',
#  'aurions',
#  'auriez',
#  'auraient',
#  'avais',
#  'avait',
#  'avions',
#  'aviez',
#  'avaient',
#  'eut',
#  'eûmes',
#  'eûtes',
#  'eurent',
#  'aie',
#  'aies',
#  'ait',
#  'ayons',
#  'ayez',
#  'aient',
#  'eusse',
#  'eusses',
#  'eût',
#  'eussions',
#  'eussiez',
#  'eussent',
#  'les']

# %%
remove_stopwords(df['tokenized_tweet'], allstopwords)
# Out:
# [['Elle',
#   'ne',
#   'devait',
#   'pas',
#   'dÃ',
#   '©',
#   'gager',
#   'la',
#   'nazi',
#   '?',
#   '?',
#   '?',
#   'https://t.co/NAGVyrhsXy'],
#  ['je',
#   'dois',
#   'faire',
#   'un',
#   'oral',
#   'en',
#   'anglais',
#   'sur',
#   'Hitler',
#   'et',
#   'sa',
#   'propagande',
#   'pour',
#   'la',
#   'section',
#   'euro',
#   'Ã',
#   '§',
#   'a',
#   'sâ',
#   '\x80',
#   '\x99',
#   'annonce',
#   'compliquÃ',
#   '©',
#   'e'],
#  ['@ambrassmoi_',
#   'A',
#   'Ã',
#   '§',
#   'a',
#   'ð',
#   '\x9f',
#   '¤',
#   '\x8f',
#   'de',
#   'ressembler',
#   'Ã',
#   'la',
#   'croix',
#   'nazi',
#   'mdrr'],
#  ['"',
#   'Par',
#   'curiositÃ',
#   '©',
#   ',',
#   'jâ',
#   '\x80',
#   '\x99',
#   'ai',
#   'voulu',
#   'Ã',
#   '©',
#   'couter',
#   'les',
#   'discours',
#   'longs',
#   'de',
#   'Hitlerâ',
#   '\x80',
#   '¦',
#   '.',
#   'on',
#   'en',
#   'trouve',
#   'sur',
#   'internet',
#   'mais',
#   'pas',
#   'sur',
#   'YouTube',
#   '.'],
#  ['@tical10',
#   '@ExBarcaFan74523',
#   '@ConflitsFrance',
#   'Mdr',
#   'deux',
#   'nazi',
#   'n',
#   'importe',
#   'quoi',
#   'ð',
#   '\x9f',
#   '¤',
#   '¦',
#   'ð',
#   '\x9f',
#   '\x8f',
#   '¼',
#   'â',
#   '\x80',
#   '\x8d',
#   'â',
#   '\x99',
#   '\x80',
#   'ï',
#   '¸',
#   '\x8f'],
#  ['"',
#   '@Henry7525',
#   '@oooANONYMEooo',
#   '@yanber_be',
#   '@alexvizorek',
#   'La',
#   'vision',
#   'sur',
#   'les',
#   'choses',
#   'du',
#   'passÃ',
#   '©',
#   'changent',
#   "l'Ã",
#   '©',
#   'volution',
#   'du',
#   'monde',
#   '.',
#   'Mais',
#   'arrÃªtez',
#   'de',
#   'mettre',
#   'tous',
#   'les',
#   '"',
#   '"',
#   'wokes',
#   '"',
#   '"',
#   'dans',
#   'le',
#   'mÃªme',
#   'panier',
#   'en',
#   'enlevant',
#   'toute',
#   'la',
#   'complexitÃ',
#   '©',
#   'et',
#   'la',
#   'nuance',
#   'de',
#   'la',
#   'rÃ',
#   '©',
#   'alitÃ',
#   '©',
#   '.',
#   "C'est",
#   'exactement',
#   'ce',
#   'que',
#   'faisait',
#   'Hitler',
#   'avec',
#   'les',
#   'juifs',
#   '.',
#   '"'],
#  ['"',
#   'Je',
#   'lis',
#   'des',
#   'choses',
#   'concernant',
#   "l'absence",
#   'de',
#   'Cyril',
#   '...'],
#  ['"',
#   'Un',
#   'docu',
#   'trÃ',
#   '¨',
#   's',
#   'trash',
#   'qui',
#   'fait',
#   'littÃ',
#   '©',
#   'ralement',
#   'lâ',
#   '\x80',
#   '\x99',
#   'apologie',
#   'de',
#   'Hitler',
#   'â',
#   '¬',
#   '\x87',
#   'ï',
#   '¸',
#   '\x8f'],
#  ['@Abordu83',
#   '30',
#   'janvier',
#   '1933',
#   ',',
#   'montÃ',
#   '©',
#   'e',
#   'au',
#   'pouvoir',
#   "d'Hitler"],
#  ['câ',
#   '\x80',
#   '\x99',
#   'est',
#   'soit',
#   'je',
#   'roule',
#   'ou',
#   'je',
#   'crÃ',
#   '¨',
#   've',
#   'https://t.co/tOSzL5QAIp'],
#  ["C'est",
#   'marrant',
#   'comme',
#   'le',
#   'militantisme',
#   'est',
#   'toujours',
#   'bridÃ',
#   '©',
#   'par',
#   'les',
#   'intÃ',
#   '©',
#   'rÃªts',
#   'personnels'],
#  ['@Saiphong',
#   'Oui',
#   'le',
#   'concours',
#   'du',
#   'Super',
#   'Nazi',
#   '...',
#   'Ya',
#   'du',
#   'monde',
#   'sur',
#   'la',
#   'ligne',
#   'de',
#   'dÃ',
#   '©',
#   'part',
#   '.'],
#  ["J'ai",
#   'vu',
#   'la',
#   'vidÃ',
#   '©',
#   'o',
#   'de',
#   'lancement',
#   'de',
#   'campagne',
#   'de',
#   'Mr',
#   'Burns',
#   ',',
#   'cet',
#   'homme',
#   'est',
#   'un',
#   'nazi',
#   '.',
#   "C'est",
#   'dÃ',
#   '©',
#   'cidÃ',
#   '©',
#   'je',
#   'vais',
#   'faire',
#   'mon',
#   'retour',
#   'dans',
#   'les',
#   'urnes',
#   'aprÃ',
#   '¨',
#   's',
#   '14',
#   'ans',
#   "d'abstinence",
#   '.'],
#  ['Je',
#   'crÃ',
#   '¨',
#   've',
#   'de',
#   'faim',
#   'mais',
#   'je',
#   'cherche',
#   'une',
#   'vidÃ',
#   '©',
#   'o',
#   'YouTube',
#   'avant',
#   'de',
#   'manger'],
#  ['@GWGoldnadel',
#   'En',
#   'fait',
#   'Zemmour',
#   'est',
#   'le',
#   'seul',
#   'Juif',
#   'que',
#   "l'on",
#   'peut',
#   'qualifier',
#   'de',
#   'nazi',
#   'sans',
#   'encourir',
#   'la',
#   'dÃ',
#   '©',
#   'sapprobation',
#   'nationale',
#   '.'],
#  ['@RTLPetitMatin',
#   '@EditionsPlon',
#   '@JeromeFlorin',
#   '@michel_mazava',
#   'Il',
#   'a',
#   'pris',
#   'un',
#   'nÃ',
#   '¨',
#   'gre',
#   'pour',
#   'Ã',
#   '©',
#   'crire',
#   'son',
#   'bouquin',
#   '?'],
#  ['Jâ',
#   '\x80',
#   '\x99',
#   'ai',
#   'envie',
#   'de',
#   'crevÃ',
#   '©',
#   'je',
#   'suis',
#   'lÃ',
#   'je',
#   'suis',
#   'revenu',
#   'Ã',
#   'la',
#   'maison',
#   'e',
#   'je',
#   'suis',
#   'dÃ',
#   '©',
#   'solÃ',
#   '©',
#   'https://t.co/qhRnTVx65q'],
#  ['@JulienOdoul',
#   '@ZemmourIer',
#   '@AlineB_83',
#   '@ZemmourEric',
#   'Pourquoi',
#   'rÃ',
#   '©',
#   'pond-tu',
#   'si',
#   'tu',
#   'reste',
#   'calme',
#   'on',
#   'voit',
#   'que',
#   'tu',
#   'crÃ',
#   '¨',
#   've',
#   'dâ',
#   '\x80',
#   '\x99',
#   'envie',
#   'de',
#   'rejoindre',
#   'Zemmour',
#   'on',
#   'connaÃ',
#   '®',
#   't',
#   'vos',
#   'tactique',
#   'politicienne',
#   'pas',
#   'Ã',
#   'nous',
#   'Julien'],
#  ['Vrai',
#   'negro',
#   'jâ',
#   '\x80',
#   '\x99',
#   'vesqui',
#   'les',
#   'vannessa',
#   'â',
#   '\x9c',
#   '\x8b',
#   'ð',
#   '\x9f',
#   '\x8f',
#   '¾',
#   'https://t.co/yzupaE3MdF'],
#  ['je',
#   'vous',
#   'dit',
#   'bonsoir',
#   '..',
#   'je',
#   'suis',
#   'crevÃ',
#   '©',
#   'et',
#   "j'ai",
#   'une',
#   'pensÃ',
#   '©',
#   'e',
#   'pour',
#   'tout',
#   'mes',
#   'twitous',
#   '..',
#   'mÃ',
#   '©',
#   'me',
#   'ceux',
#   'ou',
#   'celles',
#   'qui',
#   'ne',
#   "m'ont",
#   'pas',
#   'donnÃ',
#   '©',
#   'signe',
#   'de',
#   'vie',
#   '...',
#   'on',
#   'a',
#   'tous',
#   'nos',
#   'existences',
#   '..',
#   'mais',
#   'parfois',
#   'un',
#   'clin',
#   "d'oeil",
#   'de',
#   '10',
#   'seconde',
#   'suffit',
#   '...',
#   'bises',
#   '!',
#   '!',
#   'https://t.co/Yrh6stRl4F'],
#  ['@___flemme___',
#   'Tu',
#   'nâ',
#   '\x80',
#   '\x99',
#   'as',
#   'plus',
#   'le',
#   'negro',
#   'pass',
#   'dÃ',
#   '©',
#   'solÃ',
#   '©'],
#  ['@ActusNonStop',
#   'Rassurez',
#   'moi',
#   ',',
#   "c'est",
#   'pour',
#   'leur',
#   'bien',
#   ',',
#   "n'est",
#   'ce',
#   'pas',
#   '?',
#   'On',
#   'sait',
#   'que',
#   'vaccinÃ',
#   '©',
#   's',
#   'comme',
#   'non',
#   'vaccinÃ',
#   '©',
#   's',
#   'contaminent',
#   '.',
#   'Donc',
#   'ce',
#   "n'est",
#   'pas',
#   'sanitaire',
#   '.',
#   'Mais',
#   'au',
#   'moins',
#   'pour',
#   'leur',
#   'bien',
#   '.',
#   'Hitler',
#   ',',
#   'non',
#   '?'],
#  ['VoilÃ',
#   'qui',
#   'a',
#   'chopÃ',
#   '©',
#   'la',
#   'crÃ',
#   '¨',
#   've',
#   '!',
#   'https://t.co/bfEGuSy4Zg'],
#  ['@cemhkl',
#   '@DeTroie_',
#   '@icihoward',
#   '@Payno_Alison',
#   'Ses',
#   'idÃ',
#   '©',
#   'es',
#   'sont',
#   'pas',
#   'globalement',
#   'fausses',
#   'mec',
#   ',',
#   'Paxton',
#   'dit',
#   'que',
#   'PÃ',
#   '©',
#   'tain',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'Hitler',
#   'et',
#   'quâ',
#   '\x80',
#   '\x99',
#   'il',
#   'a',
#   'tuer',
#   'des',
#   'juifs',
#   'et',
#   'sauver',
#   'aucun',
#   ',',
#   'Zemmour',
#   'dit',
#   'que',
#   'pÃ',
#   '©',
#   'tain',
#   'a',
#   'Ã',
#   '©',
#   'changer',
#   'les',
#   'juifs',
#   'Ã',
#   '©',
#   'trangers',
#   'contre',
#   'les',
#   'juifs',
#   'franÃ',
#   '§',
#   'ais'],
#  ['@___flemme___', 'Wahhhhh', 'ce', 'negro', 'est', 'blanc', '!', '!', '!'],
#  ['Nous',
#   'savons',
#   'tous',
#   ',',
#   'sans',
#   'exception',
#   ',',
#   "qu'Eric",
#   'Zemmour',
#   "n'est",
#   'pas',
#   'le',
#   'nazi',
#   'que',
#   'cette',
#   'meute',
#   'politique',
#   'bien',
#   'pensante',
#   ',',
#   'soutenue',
#   'par',
#   'les',
#   'medias',
#   'aux',
#   'bottes',
#   ',',
#   "s'attache",
#   'Ã',
#   'dÃ',
#   '©',
#   'peindre',
#   '.',
#   'Leur',
#   'hypocrisie',
#   'les',
#   'a',
#   'dÃ',
#   '©',
#   'jÃ',
#   'disqualifiÃ',
#   '©',
#   's',
#   '.',
#   'https://t.co/CNcIuVe1Jf'],
#  ['@54_nounours',
#   'Comme',
#   'me',
#   'lâ',
#   '\x80',
#   '\x99',
#   'a',
#   'dit',
#   'un',
#   'allemand',
#   'un',
#   'jour',
#   ',',
#   'Hitler',
#   'a',
#   'tuÃ',
#   '©',
#   '6',
#   'millions',
#   'de',
#   'juifs',
#   ',',
#   'alors',
#   'quâ',
#   '\x80',
#   '\x99',
#   'il',
#   'aurait',
#   'pu',
#   'dominer',
#   'le',
#   'monde',
#   'avec',
#   'eux',
#   'Ã',
#   'ses',
#   'cÃ',
#   '´',
#   'tÃ',
#   '©',
#   's',
#   '.',
#   'Nâ',
#   '\x80',
#   '\x99',
#   'essayez',
#   'pas',
#   'de',
#   'penser',
#   'Ã',
#   'la',
#   'place',
#   'des',
#   'fous',
#   '.'],
#  ['Avec',
#   'la',
#   'mairie',
#   'de',
#   'Paris',
#   ',',
#   'ami',
#   'banlieusard',
#   ',',
#   'le',
#   'message',
#   'est',
#   'simple',
#   ':',
#   'pÃ',
#   '©',
#   'dale',
#   'ou',
#   'crÃ',
#   '¨',
#   've',
#   'ð',
#   '\x9f',
#   '\x9a',
#   '²',
#   'https://t.co/ckh39BeHhg'],
#  ['@petaramesh',
#   'Jâ',
#   '\x80',
#   '\x99',
#   'ai',
#   'appris',
#   'ce',
#   'mot',
#   'en',
#   'lisant',
#   'lâ',
#   '\x80',
#   '\x99',
#   'autobiographie',
#   'dâ',
#   '\x80',
#   '\x99',
#   'une',
#   'femme',
#   'qui',
#   'a',
#   'subi',
#   'les',
#   'camps',
#   'de',
#   'concentration',
#   'nazi'],
#  ['@DavidMn03637745',
#   '@ValRobert974',
#   'Je',
#   'fais',
#   'Ã',
#   '§',
#   'a',
#   'je',
#   'crÃ',
#   '¨',
#   've',
#   'direct',
#   'â',
#   '\x9a',
#   '°',
#   'ï',
#   '¸',
#   '\x8f'],
#  ['suis',
#   'en',
#   'train',
#   'de',
#   'chopper',
#   'la',
#   'crÃ',
#   '¨',
#   've',
#   'envie',
#   'de',
#   'mourir',
#   'lÃ'],
#  ['"',
#   '@Yoann_IV',
#   'HITLER',
#   'a',
#   'Ã',
#   '©',
#   'chouÃ',
#   '©',
#   'uniquement',
#   'parce',
#   'que'],
#  ['"', '@EPeuplu', '@FavreZian', 'Imagine', 'juste', 'un', 'rat', '.'],
#  ['"',
#   'Alors',
#   'pourquoi',
#   'a-t-il',
#   'Ã',
#   '©',
#   'tÃ',
#   '©',
#   'conÃ',
#   '§',
#   'u',
#   '?'],
#  ['@Diddy02G',
#   'Mon',
#   'negro',
#   'jâ',
#   '\x80',
#   '\x99',
#   'te',
#   'parle',
#   'de',
#   'survÃªtement',
#   'Nike',
#   'ce',
#   'genre',
#   'de',
#   'chose',
#   'man'],
#  ['@idrissaberkane',
#   'Absolument',
#   'et',
#   'pour',
#   'pouvoir',
#   'discriminer',
#   'puis',
#   'exterminer',
#   'des',
#   'millions',
#   'de',
#   'Juifs',
#   ',',
#   'Tziganes',
#   ',',
#   'vieillards',
#   ',',
#   'handicapÃ',
#   '©',
#   's',
#   ',',
#   'opposants',
#   ',',
#   'sans',
#   'que',
#   'la',
#   'population',
#   'Allemande',
#   "n'en",
#   'soit',
#   'choquÃ',
#   '©',
#   'e',
#   'et',
#   "l'accepte",
#   ',',
#   'Hitler',
#   'leur',
#   'a',
#   'fait',
#   'croire',
#   'Ã',
#   'une',
#   'Ã',
#   '©',
#   'pidÃ',
#   '©',
#   'mie',
#   'de',
#   'Ti'],
#  ["J'ai",
#   'jamais',
#   'vu',
#   'Hinti',
#   'dribbler',
#   ',',
#   'au',
#   'pire',
#   'je',
#   'crÃ',
#   '¨',
#   've',
#   'https://t.co/RwTP6ADU9x'],
#  ['@zemacplayer',
#   'ils',
#   'auraient',
#   'pu',
#   'attendre',
#   'les',
#   'patch',
#   'next',
#   'gen',
#   'quand',
#   'mÃªme',
#   ',',
#   'alors',
#   'ok',
#   'la',
#   'il',
#   'y',
#   'a',
#   'une',
#   'petite',
#   'hype',
#   'parce',
#   'que',
#   'promo',
#   'mais',
#   'quand',
#   'mÃªme',
#   "c'est",
#   'fait',
#   'vraiment',
#   'crÃ',
#   '¨',
#   've',
#   'la',
#   'dalle'],
#  ['Grosse',
#   'journÃ',
#   '©',
#   'e',
#   '...',
#   'CrevÃ',
#   '©',
#   '...',
#   'https://t.co/YpIlA4zjRL'],
#  ['ewen',
#   'il',
#   "m'a",
#   'dit',
#   'creve',
#   'pas',
#   'hein',
#   'je',
#   'suis',
#   'officiallement',
#   'le',
#   'MAILLON',
#   'faible',
#   'de',
#   'notre',
#   'equipe'],
#  ["j'en",
#   'peux',
#   'plus',
#   'de',
#   'tout',
#   'ce',
#   'cirque',
#   'mÃ',
#   '©',
#   'diatique',
#   'autour',
#   'de',
#   'zemmour',
#   'putain',
#   'montrez',
#   'nous',
#   'de',
#   'vrais',
#   'candidats',
#   'qui',
#   'ont',
#   'de',
#   'bonnes',
#   'idÃ',
#   '©',
#   'es',
#   ',',
#   'marre',
#   "d'entendre",
#   'parler',
#   'du',
#   'nouvel',
#   'Hitler'],
#  ['"',
#   '@hostrogo',
#   'Comment',
#   'Ã',
#   '§',
#   'a',
#   'on',
#   "l'a",
#   'pas',
#   'vu',
#   'venir',
#   '?',
#   '?',
#   '?',
#   "C'Ã",
#   '©',
#   'tait',
#   'littÃ',
#   '©',
#   'ralement',
#   '(',
#   'et',
#   'a',
#   'toujours',
#   'Ã',
#   '©',
#   'tÃ',
#   '©',
#   ')',
#   'le',
#   'projet',
#   'DEPUIS',
#   'LE',
#   'DEBUT',
#   '!',
#   '!',
#   '!'],
#  ['@veroniquegenest', 'Un', 'sale', 'nazi', 'oui'],
#  ['@LucieLaplace',
#   '@CedricHerrou',
#   '@FranceInsoumise',
#   '@PrimairePop',
#   'Vous',
#   'semblez',
#   'ignorer',
#   'que',
#   'certains',
#   'journalistes',
#   'sont',
#   'diplÃ',
#   '´',
#   'mÃ',
#   '©',
#   's',
#   'et',
#   'que',
#   'certains',
#   'chercheurs',
#   'stupides',
#   '.',
#   'Le',
#   'mÃ',
#   '©',
#   'pris',
#   'bride',
#   "l'intelligence",
#   '.',
#   "J'ose",
#   'espÃ',
#   '©',
#   'rer',
#   'que',
#   'les',
#   'gens',
#   'que',
#   'vous',
#   'cotoyez',
#   'ont',
#   'un',
#   'autre',
#   'Ã',
#   '©',
#   'tat'],
#  ['bro',
#   'diego',
#   'il',
#   'aime',
#   'mes',
#   'messages',
#   'Ã',
#   'la',
#   'SECONDE',
#   'mnt',
#   'je',
#   'crÃ',
#   '¨',
#   've'],
#  ['tout', 'le', 'monde', 'crÃ', '¨', 've', 'chez', 'moi'],
#  ['"',
#   '@Ed_Warner007',
#   '@JeVooZemToos',
#   '@ambassador_doge',
#   '@Valeurs',
#   'Je',
#   'confond',
#   'rien',
#   'du',
#   'tout',
#   '.',
#   "C'est",
#   'la',
#   'vÃ',
#   '©',
#   'ritÃ',
#   '©',
#   'historique',
#   'sur',
#   "l'assassin",
#   'que',
#   'ta',
#   'comme',
#   'prophÃ',
#   '¨',
#   'te',
#   '.'],
#  ['chiale', '!', '!', '!', 'et', 'CREVE', '!'],
#  ['@CarneDeTwit',
#   '@f_philippot',
#   'Alors',
#   'dÃ',
#   '©',
#   'monter',
#   'quelque',
#   'chose',
#   'dâ',
#   '\x80',
#   '\x99',
#   'aussi',
#   'simple',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'niveau',
#   'maternelle',
#   '.',
#   'Votre',
#   '1er',
#   'tweet',
#   'le',
#   'terme',
#   'nazie',
#   'apparaÃ',
#   '®',
#   't',
#   '.',
#   'Donc',
#   'vous',
#   'avez',
#   'atteint',
#   'vous',
#   'le',
#   'point',
#   'Godwin',
#   'en',
#   'un',
#   'seul',
#   'tweet',
#   'et',
#   'aprÃ',
#   '¨',
#   's',
#   'vous',
#   'dites',
#   'ne',
#   'pas',
#   'parler',
#   'de',
#   'Shoah',
#   '?',
#   '?',
#   '?',
#   'Rassu'],
#  ['@HistoireOdyssee',
#   "C'est",
#   'souvent',
#   'le',
#   'problÃ',
#   '¨',
#   'me',
#   'des',
#   'artistes',
#   ',',
#   "c'est",
#   'quand',
#   'ils',
#   'ne',
#   'sont',
#   'plus',
#   'lÃ',
#   'que',
#   'leur',
#   'Å',
#   '\x93',
#   'uvre',
#   'est',
#   'jugÃ',
#   '©',
#   'e',
#   'pour',
#   'ce',
#   "qu'elle",
#   'est',
#   '...',
#   'Du',
#   'coup',
#   ',',
#   'il',
#   'crÃ',
#   '¨',
#   've',
#   'la',
#   'faim',
#   'de',
#   'leur',
#   'vivant',
#   ',',
#   'mais',
#   'leurs',
#   'Å',
#   '\x93',
#   'uvres',
#   'rapporteront',
#   'gros',
#   ',',
#   'mais',
#   'pas',
#   'Ã',
#   'eux',
#   '...'],
#  ["J'ai",
#   'trop',
#   'faim',
#   'lÃ',
#   'la',
#   'quiche',
#   'sent',
#   'trop',
#   'bon',
#   'je',
#   'crÃ',
#   '¨',
#   've'],
#  ['@IcelandRaphael',
#   '@olivierveran',
#   '@Assur_Maladie',
#   'Bravo',
#   'bravo',
#   ',',
#   'vous',
#   'venez',
#   'dâ',
#   '\x80',
#   '\x99',
#   'apprendre',
#   'que',
#   'le',
#   'vaccin',
#   'nâ',
#   '\x80',
#   '\x99',
#   'est',
#   'pas',
#   'lÃ',
#   'pour',
#   'dire',
#   'au',
#   'Covid',
#   'â',
#   '\x80',
#   '\x9c',
#   'stop',
#   ',',
#   'tu',
#   'ne',
#   'rentre',
#   'pasâ',
#   '\x80',
#   '\x9d',
#   ',',
#   'mais',
#   'PlutÃ',
#   '´',
#   't',
#   'pour',
#   'Ã',
#   '©',
#   'viter',
#   'que',
#   'tu',
#   'crÃ',
#   '¨',
#   've',
#   'du',
#   'Covid',
#   '.'],
#  ['Prise',
#   'en',
#   'main',
#   'du',
#   'Xperia',
#   'Pro-I',
#   ':',
#   'un',
#   'smartphone',
#   'Ã',
#   '1800â',
#   '\x82',
#   '¬',
#   'qui',
#   'bride',
#   'son',
#   'capteur',
#   '1',
#   'pouce',
#   '...'],
#  ['@aidanlf',
#   'Avec',
#   'un',
#   'big',
#   'mac',
#   ',',
#   'une',
#   'heure',
#   'plus',
#   'tard',
#   'on',
#   'crÃ',
#   '¨',
#   've',
#   'la',
#   'dalle',
#   ',',
#   "ch'ais",
#   'pas',
#   'si',
#   'Ã',
#   '§',
#   'a',
#   'fait',
#   'le',
#   'mÃªme',
#   'effet',
#   'avec',
#   'lui',
#   'ð',
#   '\x9f',
#   '¤',
#   '£'],
#  ['@RERD_SNCF',
#   'Corbeil',
#   'vs',
#   'Melun',
#   ':',
#   'une',
#   'fois',
#   'encore',
#   ',',
#   'mÃªmes',
#   'problÃ',
#   '¨',
#   'mes',
#   ',',
#   'traitement',
#   'different',
#   '.',
#   'Un',
#   'favoritisme',
#   'flagrant',
#   'et',
#   'rÃ',
#   '©',
#   'current',
#   'qui',
#   'crÃ',
#   '¨',
#   've',
#   'les',
#   'Ã',
#   '©',
#   'crans',
#   'tous',
#   'les',
#   'jours',
#   'Ã',
#   'Gare',
#   'de',
#   'Lyon',
#   '@RERD_SNCF',
#   ',',
#   'quand',
#   'aurons',
#   'nous',
#   'une',
#   'explication',
#   'honnÃªte',
#   '?',
#   'https://t.co/K9F3h'],
#  ['VidÃ', '©', 'o', 'de', 'propagande', 'Nazi', 'https://t.co/WeGUNiwU9G'],
#  ['@arbolitodechoco', '@f_philippot', '@AngelaMerkel_DE', 'Es', 'nazi'],
#  ['"',
#   '#ZEMMOUR',
#   'a',
#   'Ã',
#   '©',
#   'tÃ',
#   '©',
#   'rejetÃ',
#   '©',
#   'et',
#   'exclu',
#   'de',
#   'trÃ',
#   '¨',
#   's',
#   'nombreux',
#   'groupes',
#   'officiels',
#   'pour',
#   'son',
#   '#comportement',
#   'incorrect',
#   'et',
#   'sa',
#   '#psychorigiditÃ',
#   '©',
#   ',',
#   'renseignez-vous',
#   'dans',
#   'les',
#   'mÃ',
#   '©',
#   'dias',
#   'alternatifs',
#   "d'internet",
#   'genre',
#   '#odyssÃ',
#   '©',
#   'e',
#   ',',
#   'pour',
#   'commencer',
#   '.'],
#  ['@BAN05063867',
#   "Qu'il",
#   'crÃ',
#   '¨',
#   've',
#   'ce',
#   'pourri',
#   '!',
#   'â',
#   '\x9c',
#   '\x8a',
#   'ð',
#   '\x9f',
#   '¤',
#   '¬'],
#  ['@Vmxour', 'CarrÃ', '©', 'ment', 'on', 'est', 'crevÃ', '©'],
#  ['@jospi31416',
#   '@NubePfizerise',
#   '@GagnerDeLaTune',
#   '@dre_sunshine',
#   'Un',
#   'crÃ',
#   '¨',
#   've',
#   'cÅ',
#   '\x93',
#   'ur',
#   "j'imagine"],
#  ['@licorne_8450',
#   '@PATRICKJARDIN15',
#   '@ZemmourEric',
#   '@karim_naim86',
#   'tu',
#   'as',
#   'vu',
#   'les',
#   'fans',
#   ',',
#   'admirateur',
#   'du',
#   'sabre',
#   'du',
#   'goupillon',
#   ',',
#   'anti',
#   'musulman',
#   ',',
#   'anti',
#   'juif',
#   'bref',
#   'les',
#   'nazi',
#   ',',
#   'ils',
#   'osent',
#   'tout',
#   '!',
#   'Le',
#   'tutoiement',
#   'les',
#   'insultes',
#   '.',
#   'Je',
#   'te',
#   'refile',
#   'celui-ci',
#   'pour',
#   'te',
#   'dÃ',
#   '©',
#   'fouler',
#   '!',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x89',
#   'cadeau',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x82'],
#  ['CrevÃ',
#   '©',
#   'comme',
#   'un',
#   'boudin',
#   ',',
#   'mais',
#   '...',
#   'Jeudi',
#   'picolo',
#   'quand',
#   'mÃªme',
#   '.',
#   'https://t.co/cEaU95esGN'],
#  ['@libreetserein',
#   '@lynns68gwada971',
#   'Avec',
#   'vos',
#   'doses',
#   'de',
#   'rappelle',
#   'Ã',
#   "l'infinie",
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x82',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x82',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x82',
#   'vous',
#   'allez',
#   'crevÃ',
#   '©',
#   'bien',
#   'avant',
#   'nous',
#   'et',
#   'c',
#   'dans',
#   'trÃ',
#   '¨',
#   's',
#   'bientÃ',
#   '´',
#   't',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x9c',
#   'EspÃ',
#   '¨',
#   'ces',
#   'de',
#   '0',
#   'cervel',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x82',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x82',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x82',
#   'https://t.co/12Und6GoT1'],
#  ['@f_philippot',
#   'Le',
#   'mal',
#   'nazi',
#   'se',
#   'rÃ',
#   '©',
#   'pand',
#   'Ã',
#   'nouveau',
#   'dans',
#   'le',
#   'mondeð',
#   '\x9f',
#   '\x98',
#   '\x9f'],
#  ['"',
#   '"',
#   '"',
#   'Oh',
#   'mon',
#   'Dieu',
#   ',',
#   'les',
#   'antifas',
#   'nous',
#   'attaquent',
#   '!',
#   '"',
#   '"',
#   'un',
#   'toubab',
#   'fragile',
#   '.',
#   'https://t.co/mTPE7WDgpz',
#   '"'],
#  ['"',
#   '@tessierf171',
#   'un',
#   'nÃ',
#   '¨',
#   'gre',
#   'de',
#   'service',
#   ',',
#   'un',
#   'OrÃ',
#   '©',
#   'o',
#   ',',
#   'un',
#   'oncle',
#   'Tom',
#   ',',
#   'etc',
#   '.'],
#  ['Et',
#   'tout',
#   'ce',
#   'que',
#   'tu',
#   'sais',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'que',
#   'le',
#   'reubeu',
#   'fumait',
#   'de',
#   'la',
#   'bonne',
#   'beuh'],
#  ['Les',
#   'petits',
#   'Hitler',
#   'sortent',
#   'du',
#   'bois',
#   '...',
#   'leur',
#   'monde',
#   'est',
#   'Ã',
#   'vomir',
#   '.',
#   '#fuckthenwo',
#   'https://t.co/WprU4mcXoN'],
#  ['Le',
#   'championnat',
#   'espagnol',
#   'est',
#   'entrain',
#   'de',
#   'crevÃ',
#   '©',
#   'et',
#   'il',
#   'compte',
#   'sur',
#   'nous',
#   'pour',
#   'renaÃ',
#   '®',
#   'tre'],
#  ['Mais',
#   "n'importe",
#   'quoi',
#   'il',
#   "s'ennuie",
#   'a',
#   'mourir',
#   'sa',
#   'crevÃ',
#   '©',
#   'les',
#   'yeux',
#   '#TPMP',
#   'https://t.co/h0IUcPRdp6'],
#  ['Vous',
#   'la',
#   'voyez',
#   'venir',
#   ',',
#   'la',
#   'tyrannie',
#   ',',
#   'Messieurs',
#   'les',
#   'SÃ',
#   '©',
#   'nateurs',
#   '?',
#   'Lesquels',
#   'vont',
#   'taper',
#   'du',
#   'poing',
#   'sur',
#   'la',
#   'table',
#   'pour',
#   'nommer',
#   "l'outrance",
#   "d'un",
#   'produit',
#   'expÃ',
#   '©',
#   'rimental',
#   'imposÃ',
#   '©',
#   'Ã',
#   'la',
#   'Nazi',
#   '!',
#   '@loichervepublic',
#   '@alainhoupert',
#   '@BasPhilippe',
#   '@GuillaumGontard',
#   '@MichelSavin38',
#   '@didier_rambaud',
#   '@VALLINIAndre',
#   'https://t.co/NIYDfVJn7r'],
#  ['@MaghrebiaAsala',
#   '@borderlynes',
#   '@Tenshouichi',
#   '@ThibaultSansEau',
#   'tu',
#   'vas',
#   'te',
#   'calmer',
#   'le',
#   'bamboula'],
#  ['"',
#   '@Nadya_Lou006',
#   'Depuis',
#   'la',
#   'nuit',
#   'des',
#   'temps',
#   ',',
#   'les',
#   'nations',
#   'puissantes',
#   'ont',
#   'cherchÃ',
#   '©',
#   'Ã',
#   "s'imposer",
#   'au',
#   'monde',
#   'pour',
#   'en',
#   'faire',
#   'une',
#   'province',
#   '.',
#   'Tous',
#   'se',
#   'sont',
#   'cassÃ',
#   '©',
#   'les',
#   'dents',
#   '.',
#   'Le',
#   'dernier',
#   'en',
#   'date',
#   ',',
#   "c'est",
#   'Hitler',
#   '.'],
#  ['Gio',
#   'il',
#   'me',
#   'parle',
#   'sur',
#   '4',
#   'application',
#   '..',
#   'tâ',
#   '\x80',
#   '\x99',
#   'es',
#   'pas',
#   'ma',
#   'meuf',
#   'negro',
#   '(',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'Ã',
#   'cause',
#   'de',
#   'moi',
#   ')'],
#  ['@devochk496',
#   'Mais',
#   "c'est",
#   'une',
#   'horreur',
#   'un',
#   'cauchemar',
#   '!',
#   "J'ai",
#   "l'impression",
#   "qu'elle",
#   'parle',
#   "d'une",
#   'panne',
#   'de',
#   'voiture',
#   '...',
#   'Et',
#   'elle',
#   'passe',
#   'a',
#   'la',
#   'tele',
#   'histoire',
#   'de',
#   'pousser',
#   "l'humiliation",
#   '.',
#   "J'ai",
#   'envie',
#   'de',
#   'crevÃ',
#   '©'],
#  ['@giberpa',
#   '@MathieuSlama',
#   "C'est",
#   'exactement',
#   'Ã',
#   '§',
#   'a',
#   '..',
#   'un',
#   'nazi',
#   'psychopathe',
#   'cet',
#   'homme',
#   'est',
#   'tout',
#   'ce',
#   "qu'il",
#   'y',
#   'a',
#   'de',
#   'pire',
#   '!',
#   '!',
#   'Lui',
#   'le',
#   'dieu',
#   'au',
#   'milieu',
#   'des',
#   'inutiles',
#   '..',
#   'je',
#   'reviens',
#   'encore',
#   'a',
#   'Ã',
#   '§',
#   'a',
#   'mais',
#   'cette',
#   'vidÃ',
#   '©',
#   'o',
#   "m'avait",
#   'tellement',
#   'choquÃ',
#   '©',
#   'e',
#   '!'],
#  ['@Moha_lassel', 'Xptdrrrrr', 'crÃ', '¨', 've'],
#  ['@alexandreczrl',
#   '@ElevePingouin',
#   'Clairement',
#   'hahahahaha',
#   'purÃ',
#   '©',
#   'e',
#   'il',
#   'Ã',
#   '©',
#   'tait',
#   'au',
#   'bout',
#   'de',
#   'sa',
#   'vie',
#   'mon',
#   'tel',
#   'jusquâ',
#   '\x80',
#   '\x99',
#   'Ã',
#   'quâ',
#   '\x80',
#   '\x99',
#   'il',
#   'crÃ',
#   '¨',
#   've',
#   'aux',
#   'fond',
#   'des',
#   'chiotte',
#   'vraiment',
#   'jâ',
#   '\x80',
#   '\x99',
#   'ai',
#   'mÃ',
#   '©',
#   'ritÃ',
#   '©',
#   'mon',
#   'iPhone'],
#  ['Le',
#   'negro',
#   'qui',
#   'sâ',
#   '\x80',
#   '\x99',
#   'est',
#   'envoyÃ',
#   '©',
#   'Ã',
#   'ChÃ',
#   '¢',
#   'telet',
#   'a',
#   'rÃ',
#   '©',
#   'ussi',
#   'sa',
#   'mission',
#   'lÃ',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\xad'],
#  ['@MizPoline',
#   'MÃªme',
#   'Hitler',
#   'a',
#   'de',
#   'plus',
#   'jolies',
#   'couvertures',
#   '.'],
#  ['@AldoSterone111',
#   '2/2',
#   '.',
#   'Le',
#   'plan',
#   'mondialiste',
#   'ne',
#   'visait',
#   'Ã',
#   'rien',
#   'dâ',
#   '\x80',
#   '\x99',
#   'autre',
#   'quâ',
#   '\x80',
#   '\x99',
#   'Ã',
#   'lâ',
#   '\x80',
#   '\x99',
#   'instauration',
#   'dâ',
#   '\x80',
#   '\x99',
#   'un',
#   'ordre',
#   'universel',
#   'que',
#   'Hitler',
#   ',',
#   'sâ',
#   '\x80',
#   '\x99',
#   'il',
#   'gagnait',
#   'la',
#   'guerre',
#   ',',
#   'se',
#   'proposait',
#   'dâ',
#   '\x80',
#   '\x99',
#   'imposer',
#   'sans',
#   'mÃ',
#   '©',
#   'nagement',
#   'au',
#   'monde',
#   'des',
#   'hommes',
#   '.',
#   'Ils',
#   'ont',
#   'donc',
#   'continuÃ',
#   '©',
#   'aprÃ',
#   '¨',
#   's',
#   'sa',
#   'dÃ',
#   '©',
#   'fa'],
#  ['Les',
#   'tÃªtes',
#   'de',
#   'gondoles',
#   'socialos',
#   'comme',
#   'Mussolini',
#   'et',
#   'Hitler',
#   'aiment',
#   'le',
#   'pluralisme',
#   'et',
#   'la',
#   'libertÃ',
#   '©',
#   'dâ',
#   '\x80',
#   '\x99',
#   'opinion',
#   '.',
#   'https://t.co/N7nQNz0fQ8'],
#  ['Lâ',
#   '\x80',
#   '\x99',
#   'Allemagne',
#   'et',
#   'lâ',
#   '\x80',
#   '\x99',
#   'Autriche',
#   'redeviennent',
#   'un',
#   'Ã',
#   '©',
#   'tat',
#   'nazi',
#   '...',
#   'Discriminations',
#   ',',
#   'apartheid',
#   'et',
#   'bientÃ',
#   '´',
#   't',
#   'dÃ',
#   '©',
#   'portements',
#   'et',
#   'puis',
#   'extermination',
#   '?',
#   '...',
#   'ð',
#   '\x9f',
#   '¤',
#   '¢',
#   'ð',
#   '\x9f',
#   '¤',
#   '¢',
#   'ð',
#   '\x9f',
#   '¤',
#   '®',
#   'ð',
#   '\x9f',
#   '¤',
#   '®',
#   'ð',
#   '\x9f',
#   '¤',
#   '®',
#   'ð',
#   '\x9f',
#   '¤',
#   '®',
#   'ð',
#   '\x9f',
#   '¤',
#   '®',
#   'ð',
#   '\x9f',
#   '¤',
#   '®',
#   'ð',
#   '\x9f',
#   '¤',
#   '®',
#   'https://t.co/7tKcaExJeU'],
#  ['"', '@MrJohn_dvro', 'Ah', 'mais', 'oui'],
#  ['Un',
#   'Ã',
#   '©',
#   'tat',
#   'NAZI',
#   'ne',
#   'changera',
#   'jamais',
#   'ses',
#   'idÃ',
#   '©',
#   'es',
#   'ancrÃ',
#   '©',
#   'es',
#   'dans',
#   'leur',
#   'tÃªte',
#   'de',
#   'moineau',
#   '.',
#   'https://t.co/JzXVBcYalC'],
#  ['Un',
#   'coifure',
#   'divine',
#   '.',
#   "J'ai",
#   'croisÃ',
#   '©',
#   'un',
#   'petit',
#   'reubeu',
#   'locsÃ',
#   '©',
#   ',',
#   'il',
#   'etait',
#   'magnifique',
#   '.',
#   'https://t.co/rnJiXixJFq'],
#  ['@MohAviion',
#   'Dans',
#   'les',
#   'annÃ',
#   '©',
#   'es',
#   '1900',
#   'pour',
#   'tuer',
#   'Hitler',
#   'quand',
#   'il',
#   'Ã',
#   '©',
#   'tait',
#   'enfant'],
#  ['@Nicolas68774292',
#   'On',
#   'avait',
#   'dÃ',
#   '©',
#   'jÃ',
#   'perdu',
#   'ont',
#   'les',
#   'a',
#   'quand',
#   'mÃªme',
#   'battu',
#   '+',
#   'les',
#   'nazi',
#   'qui',
#   'vole',
#   'leur',
#   'essence',
#   'pour',
#   'fuir',
#   'je',
#   'suis',
#   'mort'],
#  ['@Eoreen_', 'OH', 'LE', 'NEGRO', 'MIELLEUX'],
#  ['@CarneDeTwit',
#   '@f_philippot',
#   'En',
#   '1932',
#   'le',
#   'but',
#   'dâ',
#   '\x80',
#   '\x99',
#   'Hitler',
#   'Ã',
#   '©',
#   'tait',
#   'dÃ',
#   '©',
#   'jÃ',
#   'de',
#   'sâ',
#   '\x80',
#   '\x99',
#   'en',
#   'prendre',
#   'aux',
#   'juifs',
#   'et',
#   'faire',
#   'un',
#   'peuple',
#   'aryen',
#   'sans',
#   'handicapÃ',
#   '©',
#   's',
#   ',',
#   'lgbt',
#   'et',
#   'tzigane',
#   '.',
#   'Je',
#   'ne',
#   'savais',
#   'pas',
#   'quâ',
#   '\x80',
#   '\x99',
#   'en',
#   '2021',
#   'en',
#   'France',
#   'on',
#   'prÃ',
#   '©',
#   'conisait',
#   'la',
#   'Shoah',
#   '.',
#   'Les',
#   'mots',
#   'ont',
#   'un',
#   'sens',
#   'et',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'pou'],
#  ['Je',
#   'suis',
#   'pas',
#   'mort',
#   'je',
#   'suis',
#   'Ã',
#   'Toubab',
#   'Dialaw',
#   'https://t.co/QW7mgE1Z8H'],
#  ['@AldoSterone111',
#   '1/2-',
#   'Ce',
#   'complot',
#   'mondialiste',
#   'est',
#   "d'une",
#   'telle',
#   'ampleur',
#   "qu'il",
#   'est',
#   'difficile',
#   'de',
#   'dÃ',
#   '©',
#   'signer',
#   'un',
#   'seul',
#   'responsable.Hitler',
#   'disait',
#   'que',
#   'le',
#   'Saint',
#   'Empire',
#   'romain',
#   'devait',
#   'Ãªtre',
#   'rÃ',
#   '©',
#   'tabli',
#   'et',
#   'avait',
#   'vocifÃ',
#   '©',
#   'rÃ',
#   '©',
#   'que',
#   'le',
#   'national',
#   'socialisme',
#   'durerait',
#   'mille',
#   'ans',
#   '.'],
#  ['"',
#   '@Zeffyra1984',
#   'Ã',
#   '\x80',
#   "l'inverse",
#   'il',
#   'y',
#   'aussi',
#   'ceux',
#   'qui',
#   'jugent',
#   'les',
#   'collabos',
#   'du',
#   'passÃ',
#   '©',
#   'avec',
#   'les',
#   'yeux',
#   'du',
#   'prÃ',
#   '©',
#   'sent',
#   '.'],
#  ['@JeanBambois6',
#   '@Napoleone750',
#   'Quâ',
#   '\x80',
#   '\x99',
#   'il',
#   'aille',
#   'Ã',
#   'la',
#   'mosquÃ',
#   '©',
#   'e',
#   'rire',
#   'dEric',
#   'Zemmour',
#   '.',
#   'Sale',
#   'race'],
#  ['@fatma_cht', 'jâ', '\x80', '\x99', 'avoue', 'mÃªme', 'karatsev', 'jsp'],
#  ['@RodTapieM',
#   'Bjr',
#   'vousbonjour',
#   'vous',
#   'ne',
#   'me',
#   'connaissez',
#   'pas',
#   'cependant',
#   'votre',
#   'pÃ',
#   '¨',
#   're',
#   'et',
#   'ce',
#   'nom',
#   'tapis',
#   "m'a",
#   'donnÃ',
#   '©',
#   'la',
#   'niaque',
#   'de',
#   'plus',
#   'petit',
#   'et',
#   'vive',
#   'le',
#   'dictaphone',
#   'du',
#   'portable',
#   "j'espÃ",
#   '¨',
#   're',
#   'que',
#   'tu',
#   'vas',
#   'bien',
#   'car',
#   'je',
#   'recommence',
#   'en',
#   'passer',
#   'Ã',
#   'vous',
#   "j'espÃ",
#   '¨',
#   're',
#   'que',
#   'votre',
#   'mÃ',
#   '¨',
#   're',
#   'et',
#   'gran'],
#  ['Â',
#   '«',
#   'Â',
#   'Le',
#   'constat',
#   'que',
#   'dresse',
#   'Eric',
#   'Zemmour',
#   ',',
#   'Ã',
#   'bien',
#   'des',
#   'Ã',
#   '©',
#   'gards',
#   ',',
#   'je',
#   'le',
#   'partage',
#   ',',
#   'disons',
#   'quâ',
#   '\x80',
#   '\x99',
#   'on',
#   'a',
#   'le',
#   'mÃªmeÂ',
#   'Â',
#   '»',
#   '#EricCiotti',
#   'les',
#   'deux',
#   'Ã',
#   '\x89',
#   'ric',
#   'partagent',
#   'un',
#   'prÃ',
#   '©',
#   'nom',
#   'dâ',
#   '\x80',
#   '\x99',
#   'origine',
#   'germanique',
#   'qui',
#   'va',
#   'de',
#   'pair',
#   'avec',
#   'une',
#   'idÃ',
#   '©',
#   'ologie',
#   'identitaire',
#   '#Islamophobe',
#   '#PÃ',
#   '©',
#   'tainiste',
#   'et',
#   '#Nazi',
#   '=',
#   '2',
#   '#Fils_de_PÃ',
#   '©',
#   'tain',
#   '!',
#   'ð',
#   '\x9f',
#   '\x96',
#   '\x95',
#   'ð',
#   '\x9f',
#   '\x8f',
#   '½',
#   'https://t.co/idNbMZ3K62',
#   'https://t.co/16FAuU3sGO'],
#  ['Chui', 'un', 'negro', 'rÃ', '©', 'gulier', ',', 'pas', 'spÃ', '©', 'cial'],
#  ['@LaliCidjah',
#   '@__Denilsoon_',
#   '@RERB',
#   '@Qofficiel',
#   'Facho',
#   'â',
#   '\x80',
#   '¦',
#   'seul',
#   'argument',
#   'facho',
#   '?',
#   '?',
#   'Vous',
#   'savez',
#   'ce',
#   'que',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'le',
#   'fascisme',
#   '?',
#   'Hitler',
#   'Staline',
#   'mussolini',
#   'les',
#   'frÃ',
#   '¨',
#   'res',
#   'musulman',
#   'voici',
#   'le',
#   'Fascime',
#   '!',
#   '!',
#   '!',
#   'Va',
#   'falloir',
#   'trouver',
#   'des',
#   'arguments',
#   'plus',
#   'convaincants',
#   '!',
#   '!',
#   'Le',
#   'gauchiste',
#   '?',
#   'Voil'],
#  ['#PonoGay',
#   '#BeurGay',
#   '-',
#   'Deux',
#   'faciales',
#   'Ã',
#   'la',
#   'suite',
#   'pour',
#   'une',
#   'petite',
#   'frappe',
#   'du',
#   'quartier',
#   ':',
#   'https://t.co/O77UMWvKlA'],
#  ['"',
#   "j'ai",
#   'envie',
#   'de',
#   'pleurer',
#   'mÃ',
#   '©',
#   'lo',
#   'est',
#   'si',
#   'petit',
#   ',',
#   'si',
#   'mignon'],
#  ['"', 'Premier', 'anime', ':', 'Naruto'],
#  ['@Clelest',
#   '@ccg_ad91',
#   '@VincentLanies',
#   '@ZemmourEric',
#   'Ont',
#   'les',
#   'traites',
#   'comme',
#   'Ã',
#   '§',
#   'a',
#   'car',
#   'eux',
#   'mÃªme',
#   'traite',
#   'dâ',
#   '\x80',
#   '\x99',
#   'extrÃªme',
#   'droite',
#   ',',
#   'fasciste',
#   ',',
#   'nazi',
#   'homophobe',
#   'etc',
#   'quand',
#   'ils',
#   'nâ',
#   '\x80',
#   '\x99',
#   'ont',
#   'plus',
#   'dâ',
#   '\x80',
#   '\x99',
#   'argument'],
#  ['@MamzelleNaf',
#   'souvenir',
#   'de',
#   'fac',
#   ',',
#   'un',
#   'prof',
#   'foufou',
#   "l'eau",
#   'pure',
#   'qui',
#   'vient',
#   'de',
#   'la',
#   'montagne',
#   'sur',
#   'rÃ',
#   '©',
#   'surgence',
#   ',',
#   'avec',
#   'un',
#   'mouton',
#   'crevÃ',
#   '©',
#   'en',
#   'karstique',
#   ',',
#   'la',
#   'douve',
#   'du',
#   'foie',
#   ',',
#   'il',
#   'est',
#   'rentrÃ',
#   '©',
#   'en',
#   'urgence',
#   '.',
#   'Et',
#   'on',
#   'a',
#   'bien',
#   'rigolÃ',
#   '©',
#   '(',
#   'ceux',
#   'qui',
#   'avaient',
#   'fait',
#   'hydrogÃ',
#   '©',
#   'ologie',
#   ')'],
#  ['@AncKou_',
#   '@Bunker_D_',
#   '@GaelleGiroud',
#   'Ah',
#   'ben',
#   "c'est",
#   'sÃ',
#   '»',
#   'r',
#   "qu'en",
#   'jouant',
#   'la',
#   'fausse',
#   'neutralitÃ',
#   '©',
#   'et',
#   'en',
#   'demandant',
#   'comme',
#   'un',
#   'benÃªt',
#   'Ã',
#   'un',
#   'juif',
#   'et',
#   'Ã',
#   'un',
#   'nazi',
#   'ce',
#   "qu'est",
#   'un',
#   'juif',
#   ',',
#   'ils',
#   'vont',
#   'pas',
#   'donner',
#   'les',
#   'mÃªmes',
#   'rÃ',
#   '©',
#   'ponses',
#   '.'],
#  ['Ã',
#   '\x8a',
#   'tre',
#   'nÃ',
#   '¨',
#   'gre',
#   'se',
#   'voit',
#   'toujours',
#   ',',
#   'un',
#   'jour',
#   'ou',
#   "l'autre",
#   '.',
#   'https://t.co/H6nbsQuPXg'],
#  ['Mais',
#   "c'est",
#   'une',
#   'mentalitÃ',
#   '©',
#   'de',
#   'nazi',
#   'ca',
#   'https://t.co/0ONr0diGtV'],
#  ['@NoAsbelTown',
#   '@Esban_',
#   'Et',
#   'tu',
#   'feras',
#   'quoi',
#   'de',
#   'tous',
#   'ceux',
#   'que',
#   't',
#   'aura',
#   'torturee',
#   'pour',
#   'rien',
#   '?',
#   'Tu',
#   'devras',
#   'leur',
#   'mettre',
#   'une',
#   'balle',
#   'dans',
#   'la',
#   'tete',
#   'sinon',
#   'quand',
#   'il',
#   'sortiront',
#   'ce',
#   'seront',
#   'des',
#   'salah',
#   'abdeslam',
#   'ou',
#   'merah',
#   'que',
#   'tu',
#   'auras',
#   'cree',
#   '.'],
#  ['"', 'La', 'traque', 'des', 'nazis', '...'],
#  ['@AldoSterone111',
#   'On',
#   'aurait',
#   'surtout',
#   'jamais',
#   'dÃ',
#   '»',
#   'permettre',
#   'Ã',
#   'Hitler',
#   'de',
#   'detruire',
#   "l'Europe",
#   '.',
#   "M'enfin",
#   'bon',
#   'apparemment',
#   'a',
#   'cette',
#   'Ã',
#   '©',
#   'poque',
#   'la',
#   'les',
#   'Ã',
#   '\x89',
#   'tats',
#   'Unis',
#   'ont',
#   'accordÃ',
#   '©',
#   'des',
#   'prÃªts',
#   'trÃ',
#   '¨',
#   's',
#   'gÃ',
#   '©',
#   'nÃ',
#   '©',
#   'reux',
#   'Ã',
#   "l'Allemagne",
#   'pour',
#   "qu'elle",
#   'conduise',
#   'ses',
#   'politiques',
#   '.'],
#  ['@CamChauss',
#   'Le',
#   'pÃ',
#   '¨',
#   're',
#   'NoÃ',
#   '«',
#   'l',
#   'c',
#   'est',
#   'le',
#   '25',
#   '60',
#   '%',
#   'de',
#   'la',
#   'droite',
#   'migrÃ',
#   '©',
#   'chez',
#   'marine',
#   'pas',
#   'chez',
#   'le',
#   'petit',
#   'Hitler'],
#  ['"',
#   '@PhilippeMurer',
#   '@AldoSterone111',
#   'Si',
#   'on',
#   'fait',
#   'pas',
#   'le',
#   '#Frexit'],
#  ['@xavierbertrand',
#   '@lesRepublicains',
#   '@vpecresse',
#   'ð',
#   '\x9f',
#   '¤',
#   '£',
#   'ð',
#   '\x9f',
#   '¤',
#   '£',
#   'ð',
#   '\x9f',
#   '¤',
#   '£',
#   'ð',
#   '\x9f',
#   '¤',
#   '£',
#   'ð',
#   '\x9f',
#   '¤',
#   '£',
#   'Comment',
#   'on',
#   'dit',
#   'dÃ',
#   '©',
#   'jÃ',
#   '?',
#   'Ah',
#   'oui',
#   ':',
#   'DANS',
#   'TON',
#   'CUL',
#   'LE',
#   'NAZI',
#   '!',
#   '!',
#   '!',
#   'ð',
#   '\x9f',
#   '¤',
#   '£',
#   'ð',
#   '\x9f',
#   '¤',
#   '£',
#   'ð',
#   '\x9f',
#   '¤',
#   '£'],
#  ['Â',
#   '«',
#   'Â',
#   'Le',
#   'constat',
#   'que',
#   'dresse',
#   'Eric',
#   'Zemmour',
#   ',',
#   'Ã',
#   'bien',
#   'des',
#   'Ã',
#   '©',
#   'gards',
#   ',',
#   'je',
#   'le',
#   'partage',
#   ',',
#   'disons',
#   'quâ',
#   '\x80',
#   '\x99',
#   'on',
#   'a',
#   'le',
#   'mÃªmeÂ',
#   'Â',
#   '»',
#   '#EricCiotti',
#   'les',
#   'deux',
#   'Ã',
#   '\x89',
#   'ric',
#   'partagent',
#   'non',
#   'seulement',
#   'un',
#   'nom',
#   'dâ',
#   '\x80',
#   '\x99',
#   'origine',
#   'germanique',
#   'qui',
#   'va',
#   'de',
#   'pair',
#   'avec',
#   'une',
#   'idÃ',
#   '©',
#   'ologie',
#   'identitaire',
#   '#Islamophobe',
#   '#PÃ',
#   '©',
#   'tainiste',
#   'et',
#   '#Nazi',
#   '=',
#   '2',
#   '#Fils_de_PÃ',
#   '©',
#   'tain',
#   '!'],
#  ['@BFMTV', 'CrÃ', '¨', 've', ',', 'sombre', 'ð', '\x9f', '\x92', '©'],
#  ['Il',
#   'prenait',
#   'presque',
#   'plus',
#   'de',
#   'trucs',
#   'quâ',
#   '\x80',
#   '\x99',
#   'Hitler',
#   'https://t.co/hMacDoa2gn'],
#  ['@Kukicat7',
#   'Qui',
#   'sÃ',
#   '¨',
#   'me',
#   'le',
#   'vent',
#   'rÃ',
#   '©',
#   'colte',
#   'la',
#   'tempÃªte',
#   '.',
#   'Il',
#   'ne',
#   'faut',
#   'pas',
#   'jouer',
#   'Ã',
#   'lâ',
#   '\x80',
#   '\x99',
#   'apprenti',
#   'nazi',
#   'au',
#   'risque',
#   'de',
#   'se',
#   'brÃ',
#   '»',
#   'ler',
#   'les',
#   'ailes',
#   'lâ',
#   '\x80',
#   '\x99',
#   'ami',
#   'Gunner',
#   '.'],
#  ['@annick_OL',
#   '@aucunnomdelibre',
#   '@CommanderTorenn',
#   '@Dadoo5152',
#   '@AlainDuhamel',
#   'Un',
#   'youpin',
#   'antisÃ',
#   '©',
#   'mite',
#   '...',
#   'On',
#   'aura',
#   'tout',
#   'lu',
#   '!'],
#  ['MÃªme',
#   'la',
#   'dictature',
#   "d'Hitler",
#   'Ã',
#   '©',
#   'tait',
#   'plus',
#   'flexible',
#   'https://t.co/Mu154q5w2q'],
#  ['@PhilippeMurer', 'Pays', 'de', 'nazi'],
#  ['"',
#   "Y'a",
#   'pas',
#   'vraiment',
#   'de',
#   'fin',
#   'Ã',
#   'ce',
#   'fil',
#   ',',
#   'pas',
#   'vraiment',
#   'de',
#   'but',
#   '.',
#   '"',
#   '"',
#   "C'est",
#   'comme',
#   'Ã',
#   '§',
#   'a',
#   '"',
#   '"',
#   '.',
#   "C'est",
#   'la',
#   'rÃ',
#   '©',
#   'ponse',
#   'la',
#   'plus',
#   '"',
#   '"',
#   'logique',
#   '"',
#   '"',
#   '.',
#   "C'est",
#   '"',
#   '"',
#   'en',
#   'marche',
#   'ou',
#   'crÃ',
#   '¨',
#   've',
#   '"',
#   '"',
#   ',',
#   'tu',
#   'sais',
#   '.'],
#  ["j'creve", 'ils', 'sont', 'tous', 'beaux', 'https://t.co/gr6yaDAx4s'],
#  ['Des',
#   'aquarelles',
#   "d'Hitler",
#   'et',
#   'deux',
#   'citations',
#   'de',
#   'CÃ',
#   '©',
#   'line',
#   'sur',
#   'fond',
#   'de',
#   'Wagner',
#   'Ã',
#   '§',
#   'a',
#   'posait',
#   'sans',
#   'doute',
#   'moins',
#   'de',
#   'problÃ',
#   '¨',
#   'me',
#   '.'],
#  ['@PhilippeMurer', 'RÃ', '©', 'gime', 'nazi', '.'],
#  ['"',
#   "J'suis",
#   'toujours',
#   'sur',
#   'le',
#   'cou',
#   ',',
#   'comme',
#   'chaÃ',
#   '®',
#   'ne',
#   'en',
#   'or'],
#  ['@itsflat7',
#   'RÃ',
#   '©',
#   'gime',
#   'nazi',
#   ',',
#   'pis',
#   'comme',
#   'dans',
#   'le',
#   'temps',
#   'le',
#   'peuple',
#   "n'y",
#   'voit',
#   'que',
#   'du',
#   'feu',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x93'],
#  ['@tical10',
#   '@ExBarcaFan74523',
#   '@ConflitsFrance',
#   'Le',
#   'fameux',
#   'nazi',
#   'juif',
#   'sÃ',
#   '©',
#   'farade',
#   'sioniste',
#   'et',
#   'la',
#   'femme',
#   'fÃ',
#   '©',
#   'minise',
#   'nazi',
#   'socialiste',
#   'mdr'],
#  ['@victeurrrr',
#   '@phaztt',
#   '@EliasLeRetour',
#   'Tes',
#   'ultra',
#   'gÃªnant',
#   'avec',
#   'ta',
#   'pp',
#   'de',
#   'melchior',
#   'que',
#   'fait',
#   'le',
#   'signe',
#   'nazi',
#   '...'],
#  ['@JLGagnaire',
#   '@tcabarrus',
#   'Est-il',
#   'acceptable',
#   'de',
#   'tenir',
#   'de',
#   'tels',
#   'propos',
#   'Ã',
#   'notre',
#   'Ã',
#   '©',
#   'poque',
#   '?',
#   'Fasciste',
#   'en',
#   'puissance',
#   ',',
#   'nazi',
#   'refoulÃ',
#   '©',
#   ',',
#   'cancer',
#   'de',
#   "l'humanitÃ",
#   '©',
#   '...'],
#  ['Les',
#   'allemands',
#   'doivent',
#   'se',
#   'soulever',
#   'contre',
#   'ce',
#   'rÃ',
#   '©',
#   'gime',
#   'de',
#   'plus',
#   'en',
#   'plus',
#   'nazi',
#   '.',
#   'https://t.co/kXjc4s0h07'],
#  ['"',
#   '@Rislam2account',
#   '"',
#   '"',
#   'nazi',
#   '"',
#   '"',
#   'cmt',
#   "t'abuses",
#   'mdddr',
#   '"'],
#  ['VENDREDI',
#   "J'AI",
#   'MES',
#   'NEVEUX',
#   'YOUHOUU',
#   'JVAIS',
#   'Ã',
#   '\x8a',
#   'TRE',
#   'CREVÃ',
#   '\x89',
#   'MAIS',
#   'JSUIS',
#   'CONTENTE'],
#  ['@VaeVix',
#   '@Mart_Inangel',
#   '@Timeo_Danaos',
#   'Lâ',
#   '\x80',
#   '\x99',
#   'autoroute',
#   'Ã',
#   '40',
#   'tonnes',
#   'voir',
#   'peut-Ãªtre',
#   'plus',
#   'Ã',
#   'cause',
#   'des',
#   'batteries',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'pas',
#   'trÃ',
#   '¨',
#   's',
#   'safe',
#   'quand',
#   'tu',
#   'es',
#   'Ã',
#   'lâ',
#   '\x80',
#   '\x99',
#   'arrÃªt',
#   'avec',
#   'un',
#   'pneu',
#   'crevÃ',
#   '©'],
#  ['@idrissaberkane',
#   'Les',
#   'nazis',
#   'sont',
#   'de',
#   'retour',
#   'en',
#   'Allemagne',
#   '.',
#   '75',
#   'ans',
#   'aprÃ',
#   '¨',
#   's',
#   'leur',
#   'dÃ',
#   '©',
#   'faite',
#   'et',
#   'en',
#   'plus',
#   'ils',
#   'dirigent',
#   "l'UE",
#   '.',
#   'Belle',
#   'victoire',
#   'de',
#   'Hitler',
#   'Ã',
#   'titre',
#   'posthume',
#   '.'],
#  ['@PierreMarionnet',
#   'oui',
#   'mais',
#   '!',
#   '!',
#   '!',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'fasciste',
#   '!',
#   '!',
#   '!',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'nazi',
#   '!',
#   '!',
#   '!',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'raciste',
#   '!',
#   '!',
#   '!',
#   'https://t.co/ZarRhfeiF7'],
#  ['"',
#   '@PhilippeMurer',
#   'Le',
#   'prix',
#   'Josef',
#   'Mengele',
#   'du',
#   '"',
#   '"',
#   'MÃ',
#   '©',
#   'decin',
#   'le',
#   'plus',
#   'ignoble',
#   'de',
#   "l'annÃ",
#   '©',
#   'e',
#   '"',
#   '"',
#   'sera',
#   'remis',
#   'Ã',
#   "l'heureux",
#   'laurÃ',
#   '©',
#   'at',
#   'Ã',
#   'Munich',
#   'en',
#   'mars',
#   '2022',
#   'des',
#   'mains',
#   'mÃªmes',
#   'de',
#   'la',
#   'descendante',
#   'du',
#   'cÃ',
#   '©',
#   'lÃ',
#   '¨',
#   'bre',
#   'mÃ',
#   '©',
#   'decin',
#   'nazi',
#   '.',
#   'De',
#   'trÃ',
#   '¨',
#   's',
#   'nombreux',
#   'mÃ',
#   '©',
#   'decins',
#   'franÃ',
#   '§',
#   'ais',
#   'sont',
#   'dÃ',
#   '©',
#   'jÃ',
#   'nominÃ',
#   '©',
#   's',
#   'pour',
#   'obtenr',
#   'cette',
#   'prestigieuse',
#   'rÃ',
#   '©',
#   'compense',
#   '"'],
#  ['@djoulye',
#   '@LiorahDouge',
#   '@barriere_dr',
#   '@MahmoudZureik',
#   'Oh',
#   'un',
#   'grammar',
#   'nazi',
#   '.',
#   'Sur',
#   'un',
#   'RS',
#   'oÃ',
#   '¹',
#   'on',
#   'tape',
#   'depuis',
#   'le',
#   'tÃ',
#   '©',
#   'lÃ',
#   '©',
#   'phone',
#   '.',
#   'Quel',
#   'argumentation',
#   'en',
#   'or',
#   '.',
#   'Mme',
#   'y',
#   'est',
#   ',',
#   'et',
#   "j'ai",
#   '2',
#   'enfants',
#   'scolarisÃ',
#   '©',
#   's',
#   'en',
#   'mater',
#   'et',
#   'en',
#   'Ã',
#   '©',
#   'lÃ',
#   '©',
#   'mentaire',
#   '.',
#   'Je',
#   'suis',
#   'assez',
#   'au',
#   'courant',
#   'de',
#   'ce',
#   'qui',
#   'peut',
#   'Ãªt'],
#  ['"', '@TPtiripou', 'Je', 'condamne', 'les', 'crimes', 'du', 'nazisme', '.'],
#  ['Hitler',
#   'quand',
#   'il',
#   'a',
#   'foirÃ',
#   '©',
#   'son',
#   'putsch',
#   'https://t.co/QzHyCi6cN9'],
#  ['@R_Massing_16_66',
#   '@MireilleGerma55',
#   '@Elpis_R',
#   'Et',
#   'toi',
#   "t'as",
#   'quoi',
#   'dans',
#   'le',
#   'ciboulot',
#   ',',
#   'petit',
#   'ð',
#   '\x9f',
#   '\x90',
#   '\x91',
#   'ð',
#   '\x9f',
#   '\x90',
#   '\x91',
#   'ð',
#   '\x9f',
#   '\x90',
#   '\x91',
#   'obeis',
#   'a',
#   'Veran',
#   ',',
#   'fait',
#   'tes',
#   '10',
#   'doses',
#   'annuelles',
#   'et',
#   'crevÃ',
#   '©',
#   'bÃªte',
#   'comme',
#   'tu',
#   'esð',
#   '\x9f',
#   '\x98',
#   '\x82',
#   ',',
#   'nous',
#   'on',
#   'garde',
#   'notre',
#   'santÃ',
#   '©',
#   'non',
#   'vaxx',
#   'en',
#   'pleine',
#   'forme',
#   'sans',
#   'comorbidites'],
#  ['@PhilippeMurer',
#   'PurÃ',
#   '©',
#   'e',
#   'Hitler',
#   'est',
#   'revenu',
#   'Ã',
#   '§',
#   'a',
#   'y',
#   'est',
#   '!',
#   '!',
#   '!'],
#  ['Denvers',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'aprÃ',
#   '¨',
#   's',
#   'on',
#   'lâ',
#   '\x80',
#   '\x99',
#   'a',
#   'chopÃ',
#   '©',
#   'il',
#   'dit',
#   'Â',
#   '«',
#   'Â',
#   'changeons',
#   'de',
#   'sujetÂ',
#   'Â',
#   '»',
#   ',',
#   'negro',
#   'tâ',
#   '\x80',
#   '\x99',
#   'es',
#   'plus',
#   'dans',
#   'notre',
#   'groupe',
#   'sale',
#   'haramiste',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\xad'],
#  ['"', 'Dans', 'mes', 'archives', ':'],
#  ['Restaurant',
#   'Manager',
#   'â',
#   '\x80',
#   '\x93',
#   'Creve',
#   'Coeur',
#   ',',
#   'MOÂ',
#   '63141',
#   'https://t.co/3WhUqMeYw9'],
#  ['"',
#   '@LindaKebbab',
#   'Tout',
#   'nos',
#   'souhaits',
#   'de',
#   'bon',
#   'rÃ',
#   '©',
#   'tablissement',
#   'Ã',
#   'ces',
#   'courageuses',
#   'Fonctionnaires',
#   'de',
#   'Police',
#   ',',
#   'soyez',
#   'assurÃ',
#   '©',
#   'es',
#   'que',
#   'nos',
#   'priÃ',
#   '¨',
#   'res',
#   'vous',
#   'accompagne',
#   'Ã',
#   '©',
#   'galement',
#   '.'],
#  ['@eden_dsx',
#   'CrÃ',
#   '¨',
#   've',
#   'en',
#   'enfer',
#   'et',
#   'avec',
#   'tes',
#   'convictions',
#   'Ã',
#   'deux',
#   'francs',
#   'sale',
#   'pute'],
#  ['@neigienfb',
#   '@Wolfa_93',
#   '@lekrokow',
#   '@PierreJov5',
#   '@thevone7',
#   '@sugarbzbyz',
#   "C'est",
#   'quoi',
#   'ces',
#   'conneries',
#   '?',
#   'Hitler',
#   'aussi',
#   'avait',
#   'des',
#   'sympathisants',
#   'et',
#   'des',
#   'ennemies',
#   ',',
#   'Ã',
#   '§',
#   'a',
#   'veut',
#   'dire',
#   "qu'il",
#   'Ã',
#   '©',
#   'tait',
#   'dans',
#   'le',
#   'vrai',
#   '?',
#   'Ã',
#   '\x87',
#   'a',
#   'vous',
#   'arrive',
#   'de',
#   'rÃ',
#   '©',
#   'flÃ',
#   '©',
#   'chir',
#   '?'],
#  ['Wesh',
#   'c',
#   'est',
#   'le',
#   'nouveau',
#   'hitler',
#   'le',
#   'gars',
#   'https://t.co/1YXxH4Njct'],
#  ['@PhilippeMurer',
#   'Rien',
#   'de',
#   'nouveau',
#   'sous',
#   'le',
#   'soleil',
#   '.',
#   'Les',
#   'plus',
#   'grands',
#   'supporters',
#   'du',
#   'rÃ',
#   '©',
#   'gime',
#   'nazi',
#   'renouent',
#   'avec',
#   'leur',
#   'histoire',
#   ':',
#   'Allemagne',
#   ',',
#   'Autriche',
#   ',',
#   'France',
#   'en',
#   'tÃªte'],
#  ['@Alphanumrique2',
#   'Il',
#   'faut',
#   'peut',
#   'Ãªtre',
#   'dÃ',
#   '©',
#   'jÃ',
#   'lui',
#   'dire',
#   'que',
#   "c'Ã",
#   '©',
#   'tait',
#   "l'extrÃªme",
#   'gauche',
#   'Hitler',
#   "c'est",
#   'le',
#   'premier',
#   'truc',
#   'que',
#   "j'ai",
#   'appris',
#   'a',
#   "l'Ã",
#   '©',
#   'cole',
#   'sur',
#   'la',
#   '2GM',
#   '.',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x91'],
#  ['@TPMP',
#   '@C8TV',
#   'BenhaÃ',
#   '¯',
#   'm',
#   '+',
#   'Elmalleh',
#   "c'est",
#   'pas',
#   'possible',
#   ',',
#   'je',
#   'zappe',
#   '.',
#   'Quant',
#   'Ã',
#   'Cyril',
#   ',',
#   "c'est",
#   'peut-Ãªtre',
#   "qu'il",
#   'faut',
#   'Ãªtre',
#   'con',
#   'pour',
#   'porter',
#   'un',
#   'blouson',
#   'de',
#   "m'as-tu-vu",
#   'en',
#   'studio',
#   ',',
#   'au',
#   'risque',
#   "d'attraper",
#   'la',
#   'crÃ',
#   '¨',
#   've',
#   'quand',
#   'on',
#   'sort',
#   '...'],
#  ['MÃªme', 'hitler', 'est', 'choquer', 'https://t.co/XGxExkth68'],
#  ['On',
#   'voit',
#   'que',
#   'heeseung',
#   'je',
#   'crÃ',
#   '¨',
#   've',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\xad',
#   'https://t.co/JpaG95xWtm'],
#  ['@tigeraido',
#   'Tâ',
#   '\x80',
#   '\x99',
#   'es',
#   'sortie',
#   'avec',
#   'hitler',
#   'ou',
#   'quoi'],
#  ['@MushobekwaMa',
#   'Si',
#   'Hitler',
#   'Ã',
#   '©',
#   'tait',
#   'vivant',
#   'il',
#   "n'allait",
#   'pas',
#   'ouvrir',
#   'sa',
#   'bouche',
#   'pour',
#   'parler',
#   ',',
#   'il',
#   "n'y",
#   'a',
#   "qu'en",
#   'RDC',
#   'oÃ',
#   '¹',
#   'les',
#   'prÃ',
#   '©',
#   'dateurs',
#   ',',
#   'voleurs',
#   ',',
#   'ont',
#   'le',
#   'courage',
#   'de',
#   'parler',
#   'sans',
#   'honte',
#   ',',
#   'pendant',
#   'le',
#   'rÃ',
#   '©',
#   'gime',
#   'sanguinaire',
#   'incarnÃ',
#   '©',
#   'par',
#   'la',
#   'kabilie',
#   'le',
#   'vol',
#   'est',
#   'une',
#   'compÃ',
#   '©',
#   'tition',
#   'et'],
#  ['@JReberlan',
#   '@CPASGAGNE69',
#   '@christine_kelly',
#   '@franceinter',
#   'Vous',
#   'faites',
#   "l'Ã",
#   '©',
#   'loge',
#   'de',
#   "l'extrÃªme",
#   'droite',
#   'Hitler',
#   'a',
#   'mis',
#   "l'europe",
#   'chaos',
#   "c'est",
#   'pour',
#   'Ã',
#   '§',
#   'a',
#   "qu'il",
#   'fallait',
#   "l'UE"],
#  ['@cardJulien',
#   'Pfizer',
#   '.',
#   "J'ai",
#   'Ã',
#   '©',
#   'tÃ',
#   '©',
#   'malade',
#   '12h',
#   'Ã',
#   'la',
#   '2e',
#   'injection',
#   'et',
#   'lÃ',
#   'actuellement',
#   'je',
#   'suis',
#   'crevÃ',
#   '©',
#   'et',
#   'mes',
#   'reins',
#   'dÃ',
#   '©',
#   'connent'],
#  ['@MathieuSlama', 'Peut', 'on', 'dÃ', '©', 'battre', 'avec', 'un', 'nazi'],
#  ['comment',
#   'je',
#   'fais',
#   'faire',
#   'vous',
#   'voulez',
#   'que',
#   'je',
#   'crÃ',
#   '¨',
#   've',
#   'ou',
#   'quoi',
#   '?',
#   '?',
#   'oÃ',
#   '¹',
#   'est',
#   'ce',
#   'que',
#   'je',
#   'vais',
#   'regarder',
#   'modern',
#   'family',
#   'pour',
#   'la',
#   '7eme',
#   'fois',
#   '?',
#   '?',
#   '?',
#   'https://t.co/iXylvqEroT'],
#  ['"',
#   '@feraiuncourrier',
#   '@yesorno32845159',
#   '@batiste17180',
#   '@CValande',
#   '@ZemmourEric',
#   'Vous',
#   'y',
#   'Ã',
#   '©',
#   'tiez',
#   'oÃ',
#   '¹',
#   'en',
#   '39',
#   'lorsque',
#   'les',
#   'troupes',
#   'allemandes',
#   'ont',
#   'mis',
#   'la',
#   'France',
#   'Ã',
#   'genoux',
#   'en',
#   '1',
#   'mois',
#   '.'],
#  ['@kennedysneant',
#   '@Lencyclopediste',
#   "C'est",
#   'pas',
#   'le',
#   'sujet',
#   ',',
#   'je',
#   'disais',
#   'pas',
#   'Ã',
#   '§',
#   'a',
#   'pour',
#   'dire',
#   'que',
#   'les',
#   'musulmans',
#   'Ã',
#   '©',
#   'taient',
#   'nazi',
#   'juste',
#   'que',
#   "l'attrait",
#   "d'hitler",
#   'pour',
#   "l'islam",
#   'Ã',
#   '©',
#   'tait',
#   'rÃ',
#   '©',
#   'el'],
#  ['@Nazi_m18',
#   'Hamilton',
#   'veut',
#   'sucer',
#   'tout',
#   'le',
#   'monde',
#   'pour',
#   'ce',
#   'faire',
#   'bien',
#   'voir',
#   'a',
#   'en',
#   'devient',
#   'complÃ',
#   '¨',
#   'tement',
#   'comique'],
#  ['@Portes_Thomas',
#   '#AnneMaSÅ',
#   '\x93',
#   'urAnne',
#   ',',
#   'si',
#   'je',
#   'te',
#   'disais',
#   'ce',
#   'que',
#   'vois',
#   'venir',
#   '...',
#   'Anne',
#   ',',
#   'ma',
#   'sÅ',
#   '\x93',
#   'ur',
#   'Anne',
#   ',',
#   "j'arrive",
#   'pas',
#   'y',
#   'croire',
#   ',',
#   "c'est",
#   'comme',
#   'un',
#   'cauchemar',
#   ',',
#   'sale',
#   'cafard',
#   '...',
#   'elle',
#   'ressort',
#   'de',
#   'sa',
#   'taniÃ',
#   '¨',
#   're',
#   ',',
#   'la',
#   'nazi',
#   'nostalgie',
#   '...',
#   'elle',
#   'a',
#   'pignon',
#   'sur',
#   'rue',
#   ',',
#   'des',
#   'adeptes',
#   ',',
#   'un',
#   'parti',
#   '...',
#   'la',
#   'vo'],
#  ['"',
#   "Z'humaine",
#   'elle',
#   'a',
#   'rouspÃ',
#   '©',
#   'tÃ',
#   '©',
#   'en',
#   'rentrant',
#   ':',
#   '"',
#   '"',
#   'oh',
#   'non',
#   '!',
#   "J'en",
#   'ai',
#   'marre',
#   '!',
#   'AprÃ',
#   '¨',
#   's',
#   'les',
#   'trains',
#   'supprimÃ',
#   '©',
#   's',
#   ',',
#   'le',
#   'pneu',
#   'crevÃ',
#   '©',
#   ',',
#   'du',
#   'vomi',
#   'partout',
#   '!',
#   '"',
#   '"',
#   '...',
#   'Ben',
#   'les',
#   'trains',
#   'et',
#   'le',
#   'pneu',
#   ',',
#   'cÃ',
#   '©',
#   'pas',
#   'nous',
#   '!',
#   'On',
#   'y',
#   'peut',
#   'rien',
#   '.',
#   'Faut',
#   'pas',
#   'ezagÃ',
#   '©',
#   'rer',
#   'konmÃªme',
#   '!',
#   '"'],
#  ['@Alpha_Drek',
#   'Ah',
#   'ouais',
#   'bah',
#   'tu',
#   'a',
#   'eu',
#   'la',
#   'crÃ',
#   '¨',
#   've',
#   'au',
#   'taf'],
#  ['"',
#   '@lobs',
#   '"',
#   '"',
#   'Antifas',
#   '"',
#   '"',
#   'ce',
#   'noble',
#   'mot',
#   'de',
#   'gauche',
#   'qui',
#   'cache',
#   'une',
#   'violence',
#   'digne',
#   'des',
#   'nazis',
#   'en',
#   '39',
#   '.',
#   '#antifas',
#   '#nazi',
#   '#hitler',
#   '"'],
#  ['Lâ',
#   '\x80',
#   '\x99',
#   'Autriche',
#   ',',
#   'lâ',
#   '\x80',
#   '\x99',
#   'autre',
#   'pays',
#   'dâ',
#   '\x80',
#   '\x99',
#   'Hitlerâ',
#   '\x80',
#   '¦',
#   '@AustriainFR',
#   'https://t.co/FoRNJAbB0H'],
#  ['"',
#   '@chrisoff10',
#   '@LaurentOzon',
#   '@Sauvadet',
#   'TrÃ',
#   '¨',
#   's',
#   'loin',
#   'c',
#   'sÃ',
#   '»',
#   'r',
#   ',',
#   'mÃªme',
#   'si',
#   'Ã',
#   '§',
#   'a',
#   'sent',
#   'la',
#   'fin',
#   'de',
#   'la',
#   'fÃªte',
#   'pour',
#   'beaucoup',
#   ',',
#   'donc',
#   'par',
#   'extension',
#   'pour',
#   'tous',
#   '!',
#   '!',
#   '!'],
#  ['@Elsa_Gambin',
#   'Je',
#   'les',
#   'ai',
#   'tous',
#   'gardÃ',
#   '©',
#   's',
#   'depuis',
#   '3',
#   'ou',
#   '4',
#   'ans',
#   'maintenant',
#   ',',
#   'je',
#   'voulais',
#   'faire',
#   'un',
#   'machin',
#   'artistico-sociologique',
#   'mais',
#   'je',
#   'suis',
#   'tellement',
#   'fatiguÃ',
#   '©',
#   'e',
#   'mentalement',
#   'que',
#   "j'arrive",
#   'pas',
#   'Ã',
#   'structurer',
#   'le',
#   'bouzin',
#   '!',
#   'En',
#   'tout',
#   'cas',
#   "c'est",
#   'flagrant',
#   ',',
#   "j'en",
#   'utilise',
#   'de',
#   'moins',
#   'en'],
#  ['"',
#   'Câ',
#   '\x80',
#   '\x99',
#   'est',
#   'Ã',
#   'quel',
#   'gouvernement',
#   'sera',
#   'le',
#   'plus',
#   'abject',
#   '..',
#   '100euros',
#   'dâ',
#   '\x80',
#   '\x99',
#   'amende',
#   'pour',
#   'les',
#   '+',
#   'de',
#   '60',
#   'ans',
#   'non',
#   'vaxx',
#   'en',
#   'GrÃ',
#   '¨',
#   'ce',
#   '!'],
#  ['@724148_1993',
#   'Je',
#   'mange',
#   ',',
#   'je',
#   'rÃ',
#   '©',
#   'vise',
#   'mon',
#   'contrÃ',
#   '´',
#   'le',
#   'sur',
#   'Hitler',
#   'jv',
#   'parler',
#   'Ã',
#   'cette',
#   'salope',
#   'irrespectueuse'],
#  ['"', 'Hitler', 'Ã', 'Hermann', 'Rauschning', ':'],
#  ["J'suis", 'crevÃ', '©', '.'],
#  ['"',
#   'Au',
#   'XXEME',
#   'siÃ',
#   '¨',
#   'cle',
#   ',',
#   'le',
#   'stÃ',
#   '©',
#   'rÃ',
#   '©',
#   'otype',
#   'du',
#   'fasciste',
#   'nazi',
#   'Ã',
#   '©',
#   'tait',
#   'un',
#   'homme',
#   'blanc',
#   ',',
#   'de',
#   'bonne',
#   'famille',
#   ',',
#   'svt',
#   'bourgeois',
#   '.'],
#  ['ce',
#   'nazi',
#   'bon',
#   'teint',
#   'au',
#   'geste',
#   'menaÃ',
#   '§',
#   'ant',
#   'est',
#   'irrespirable',
#   'â',
#   '\x9c',
#   '\x8a',
#   'â',
#   '\x9c',
#   '\x8a',
#   'â',
#   '\x9c',
#   '\x8a',
#   'https://t.co/A1l06svl0o'],
#  ['"',
#   'On',
#   'ne',
#   'vous',
#   'laissera',
#   'pas',
#   'faire',
#   'tellement',
#   'vous',
#   'Ãªtes',
#   'inhumain'],
#  ['le',
#   'nouvel',
#   'hitler',
#   'on',
#   "l'a",
#   'Schwab',
#   'a',
#   'dit',
#   'que',
#   'Macron',
#   'est',
#   'le',
#   'GUIDE',
#   '(',
#   'le',
#   'Fuhreur',
#   ')',
#   'https://t.co/WM1OvcknuZ'],
#  ['Sale', 'race', "d'Ã", '©', 'goÃ', '¯', 'stes', 'de', 'merde'],
#  ['Lyndon',
#   'souffrait',
#   "d'un",
#   'trouble',
#   ',',
#   'le',
#   'syndrome',
#   'de',
#   'fatigue',
#   'chronique',
#   ',',
#   'dont',
#   'il',
#   'fut',
#   'diagnostiquÃ',
#   '©',
#   '.',
#   'Pour',
#   'faire',
#   'simple',
#   'il',
#   'Ã',
#   '©',
#   'tait',
#   'constamment',
#   'fatiguÃ',
#   '©',
#   'pendant',
#   'de',
#   'longues',
#   'pÃ',
#   '©',
#   'riodes',
#   ',',
#   'et',
#   'malgrÃ',
#   '©',
#   'de',
#   'gros',
#   'sommeils',
#   '(8',
#   'heures',
#   ')',
#   ',',
#   'il',
#   'Ã',
#   '©',
#   'tait',
#   'crevÃ',
#   '©',
#   '(',
#   'Et',
#   'faisait',
#   'aussi',
#   'des',
#   'malaises',
#   '.',
#   ')',
#   '.',
#   '12/43'],
#  ['Le',
#   'mec',
#   'shootÃ',
#   '©',
#   'au',
#   'vaccin',
#   'prÃªt',
#   'Ã',
#   'se',
#   'faire',
#   'injecter',
#   '14',
#   'doses',
#   'mais',
#   'qui',
#   'crÃ',
#   '¨',
#   've',
#   'de',
# ...
#   'riode',
#   'nazi',
#   'lâ',
#   '\x80',
#   '\x99',
#   'Ã',
#   '\x89',
#   'tat',
#   'autrichien',
#   'nâ',
#   '\x80',
#   '\x99',
#   'existait',
#   'plus',
#   ',',
#   'voilÃ',
#   ',',
#   'je',
#   'sais',
#   'pas',
#   'comment',
#   'un',
#   'Ã',
#   '\x89',
#   'tat',
#   'inexistant',
#   'pouvait',
#   'imposer',
#   'quoi',
#   'que',
#   'ce',
#   'soit'],
#  ['@Hm_stmlr',
#   'oh',
#   'le',
#   'compte',
#   'bien',
#   'fn',
#   'bien',
#   'nazi',
#   "qu'il",
#   'a',
#   'ce',
#   'bougre'],
#  ['@GaspardGlanz',
#   'en',
#   'mÃªme',
#   'temps',
#   'mettre',
#   'en',
#   'avant',
#   'la',
#   'symphonie',
#   'dirigÃ',
#   '©',
#   'e',
#   'par',
#   'un',
#   'nazi',
#   'convaincu',
#   ',',
#   "c'est",
#   'peut',
#   'Ãªtre',
#   'pas',
#   'trÃ',
#   '¨',
#   's',
#   'pertinent',
#   '.'],
#  ['"',
#   '@Oliv_nissart',
#   '@CNEWS',
#   'Moi',
#   "j'ai",
#   'des',
#   'effets',
#   'secondaires',
#   'du',
#   'surprenne',
#   'au',
#   'mÃ',
#   '©',
#   'lange',
#   'des',
#   'nvx',
#   'vaccins',
#   'parce',
#   "qu'enfant",
#   'je',
#   "n'en",
#   'avais',
#   'pas'],
#  ['Rois',
#   'de',
#   'rien',
#   'du',
#   'tout',
#   'c',
#   'juste',
#   'quâ',
#   '\x80',
#   '\x99',
#   'on',
#   'crÃ',
#   '¨',
#   've',
#   'la',
#   'dalle',
#   'on',
#   'mange',
#   'et',
#   'on',
#   'remange',
#   'les',
#   'miettes',
#   'comme',
#   'des',
#   'rats',
#   ',',
#   'ces',
#   'gros',
#   'clochards',
#   'lÃ',
#   'ils',
#   'veulent',
#   'rien',
#   'sortir',
#   'ptdrrrrrr',
#   'https://t.co/lc0rpL0ZWe'],
#  ['"',
#   'A',
#   '#Lille',
#   ',',
#   'furieux',
#   "d'avoir",
#   'Ã',
#   '©',
#   'tÃ',
#   '©',
#   'renvoyÃ',
#   '©',
#   ',',
#   'il',
#   'crÃ',
#   '¨',
#   've',
#   'les',
#   'pneus',
#   "d'une",
#   'voiture',
#   'de',
#   'sa',
#   'sociÃ',
#   '©',
#   'tÃ',
#   '©',
#   '.',
#   'Il',
#   'a',
#   'Ã',
#   '©',
#   'tÃ',
#   '©',
#   'interpellÃ',
#   '©',
#   'et',
#   'placÃ',
#   '©',
#   'en',
#   'garde',
#   'Ã',
#   'vue'],
#  ['"',
#   '@FionaLazaar',
#   '@E_DupondM',
#   '@AN_DroitsFemmes',
#   '@RixainMP',
#   '@BCouillard33',
#   '@celinecalvez',
#   '@BattistelMarie',
#   '@brigitte_liso',
#   '@G_GouffierCha',
#   '@AlbaneGaillot',
#   '@GaelLeBohec',
#   '#Proces',
#   '#GeorgesTron',
#   '@E_DupondM',
#   'dÃ',
#   '©',
#   'calre',
#   '"',
#   '"',
#   'Ã',
#   '\x80',
#   '[',
#   'sa',
#   ']',
#   'place',
#   ',',
#   'je',
#   'vous',
#   'sauterai',
#   'Ã',
#   'la',
#   'gorge',
#   '"',
#   '"'],
#  ['"',
#   '@Henintsooaa',
#   'Hitler',
#   'avait',
#   'plus',
#   'de',
#   'stat',
#   'que',
#   'Merkel',
#   'pourtant',
#   'on',
#   'ne',
#   'veut',
#   'pas',
#   'de',
#   'son',
#   'retour'],
#  ['Par',
#   'pitiÃ',
#   '©',
#   'Ã',
#   '©',
#   'vitez',
#   'de',
#   'faire',
#   'les',
#   'grammar',
#   'nazi',
#   'quand',
#   'vous',
#   'savez',
#   'pas',
#   'Ã',
#   '©',
#   'crire',
#   'je',
#   'vous',
#   'en',
#   'conjure',
#   'vous',
#   'Ãªtes',
#   'trop',
#   'nazes'],
#  ['@Mustinefustine',
#   '@malopedia',
#   'Je',
#   'suis',
#   'sans',
#   'voix',
#   'â',
#   '\x80',
#   '¦',
#   'aimer',
#   'son',
#   'pays',
#   ',',
#   'sa',
#   'culture',
#   ',',
#   'ses',
#   'traditions',
#   ',',
#   'ses',
#   'paysages',
#   ',',
#   'son',
#   'patrimoine',
#   'ne',
#   'fait',
#   'pas',
#   'de',
#   'toi',
#   'un',
#   'nazi',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x82',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'tout',
#   'Ã',
#   'fait',
#   'vertueux',
#   'faut',
#   'arrÃªter'],
#  ['@cinqone',
#   '@dawnwreck',
#   'Wola',
#   'et',
#   'lui',
#   'en',
#   'dirais',
#   'un',
#   'nazi',
#   'avec',
#   'sa',
#   'tÃªte',
#   'en',
#   'dirais',
#   'un',
#   'coup',
#   'de',
#   'poing'],
#  ['@Yunees16',
#   '@Shaunzpro',
#   'Je',
#   'sais',
#   'pas',
#   'comment',
#   'tu',
#   'fais',
#   'mek',
#   'm',
#   ',',
#   'dÃ',
#   '©',
#   'jÃ',
#   'avec',
#   'le',
#   'chauffage',
#   'sur',
#   '20',
#   'je',
#   'crÃ',
#   '¨',
#   've',
#   'de',
#   'chaud',
#   'mdr'],
#  ['Jâ',
#   '\x80',
#   '\x99',
#   'ai',
#   'bloquer',
#   'ma',
#   'famille',
#   'sur',
#   'whatsapp',
#   'je',
#   'suis',
#   'vraiment',
#   'une',
#   'sale',
#   'race'],
#  ['de',
#   'toutes',
#   'faÃ',
#   '§',
#   'ons',
#   ',',
#   "c'est",
#   'une',
#   'mascarade',
#   '.',
#   'personne',
#   "n'est",
#   'mort',
#   'et',
#   'le',
#   'masque',
#   'sert',
#   'Ã',
#   'rien',
#   '#nazi',
#   '#GiletsJaunes'],
#  ['Ah', 'je', 'crÃ', '¨', 've', 'de', 'froid'],
#  ['@Weatherboy_fr',
#   '@ButchCoolidge11',
#   '@DamienRieu',
#   'Bah',
#   'oui',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'les',
#   'franÃ',
#   '§',
#   'ais',
#   'qui',
#   'ont',
#   'Ã',
#   '©',
#   'lus',
#   'hitler',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'connuâ',
#   '\x80',
#   '¦',
#   'gÃ',
#   '©',
#   'nie',
#   '!'],
#  ['@mormach',
#   'Pitoyable',
#   'cette',
#   'information',
#   'dirigÃ',
#   '©',
#   'e',
#   '!',
#   '!',
#   '!',
#   'On',
#   'en',
#   'crÃ',
#   '¨',
#   've',
#   '!',
#   '!',
#   '!'],
#  ['@WillyForest',
#   'C',
#   'est',
#   'une',
#   'obsession',
#   'chez',
#   'toi',
#   'le',
#   'Melenchon',
#   '?',
#   'ð',
#   '\x9f',
#   '¤',
#   '£',
#   'tu',
#   'crois',
#   'qu',
#   'il',
#   'y',
#   'a',
#   'que',
#   'lui',
#   'comme',
#   'opposant',
#   'le',
#   'nazillon',
#   'fragile',
#   '!',
#   '!',
#   'Va',
#   'au',
#   'meeting',
#   'de',
#   'ton',
#   'hitler',
#   'et',
#   'fait',
#   'pas',
#   'chier',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x81',
#   'Ã',
#   'croire',
#   'qu',
#   'il',
#   'y',
#   'a',
#   'que',
#   'les',
#   'antifasð',
#   '\x9f',
#   '¤',
#   '£'],
#  ['"',
#   'Hitler',
#   'nâ',
#   '\x80',
#   '\x99',
#   'a',
#   'quâ',
#   '\x80',
#   '\x99',
#   'Ã',
#   'bien',
#   'se',
#   'tenir'],
#  ['@jepousse10kgau',
#   'Inscrit',
#   'toi',
#   'sur',
#   'le',
#   'site',
#   'rejoint',
#   'mon',
#   'groupe',
#   'de',
#   'nazi'],
#  ['@Delc0_',
#   'Sah',
#   'tu',
#   'peux',
#   'l',
#   'dire',
#   'le',
#   'plus',
#   'gros',
#   'nazi',
#   "l'enfant",
#   'de',
#   'Hitler'],
#  ['@Alextrxm',
#   'Quand',
#   ',',
#   'certains',
#   'jours',
#   ',',
#   'on',
#   'est',
#   'un',
#   'pneu',
#   'crevÃ',
#   '©'],
#  ['@luis53057371',
#   '@BFMTV',
#   'Ptdrrr',
#   'Ã',
#   '\x89',
#   'ric',
#   'carrÃ',
#   '©',
#   'ment',
#   'on',
#   "l'appelle",
#   'par',
#   'con',
#   'petit',
#   'nom',
#   'maintenant',
#   "d'accord",
#   '.',
#   'Et',
#   'sinon',
#   'Hitler',
#   'il',
#   'Ã',
#   '©',
#   'tait',
#   'gentil',
#   'ou',
#   'pas',
#   'du',
#   'coup',
#   '?',
#   'Vous',
#   "m'avez",
#   'pas',
#   'rÃ',
#   '©',
#   'pondu'],
#  ['Cette',
#   'crÃ',
#   '¨',
#   've',
#   'monstre',
#   'encore',
#   ',',
#   'Ã',
#   'croire',
#   'jâ',
#   '\x80',
#   '\x99',
#   'ai',
#   'pris',
#   'un',
#   'abonnement'],
#  ['@LarryBambelle6',
#   '@txipironcito',
#   'Hitler',
#   'en',
#   'a',
#   'rÃªvÃ',
#   '©',
#   "l'UE",
#   'le',
#   'fait',
#   '!'],
#  ['"',
#   'Une',
#   'chose',
#   'est',
#   'sÃ',
#   '»',
#   're',
#   ':',
#   'quiconque',
#   'lÃ',
#   '¨',
#   'vera',
#   'son',
#   'Ã',
#   '©',
#   'pÃ',
#   '©',
#   'e',
#   'pÃ',
#   '©',
#   'rira',
#   'par',
#   "l'Ã",
#   '©',
#   'pÃ',
#   '©',
#   'e',
#   '!',
#   '..',
#   'Pour',
#   'en',
#   'savoir',
#   'plus',
#   ',',
#   'demandez',
#   'un',
#   'peu',
#   'au',
#   '"',
#   '"',
#   'fortiche',
#   '"',
#   '"',
#   'Hitler',
#   '!',
#   '..',
#   'Il',
#   'en',
#   'sait',
#   'quelque',
#   'chose',
#   ',',
#   'lui',
#   '!',
#   'Et',
#   'le',
#   'monde',
#   'entier',
#   ',',
#   'Ã',
#   'sa',
#   'suite',
#   '!',
#   '..',
#   'https://t.co/CF8B7pkl5w',
#   '"'],
#  ['@frostbeckett',
#   'purÃ',
#   '©',
#   'e',
#   'je',
#   "t'imagine",
#   'le',
#   'faire',
#   'et',
#   'ton',
#   'air',
#   'dÃ',
#   '©',
#   'goutÃ',
#   '©',
#   'je',
#   'crÃ',
#   '¨',
#   've',
#   "j'aurais",
#   'trop',
#   'aimÃ',
#   '©',
#   'voir',
#   'Ã',
#   '§',
#   'a',
#   'ndbxks',
#   'le',
#   'pauvre',
#   'bb'],
#  ['@LeFcl5600',
#   '@Cyrilhanouna',
#   'Il',
#   'est',
#   'vaccinÃ',
#   '©',
#   '...',
#   'ah',
#   'la',
#   'la',
#   'les',
#   'gens',
#   'qui',
#   'crachent',
#   'sur',
#   'les',
#   'non',
#   'vaccinÃ',
#   '©',
#   's',
#   '.',
#   'moi',
#   'je',
#   'ne',
#   'peux',
#   'pas',
#   'le',
#   'faire',
#   'contre',
#   'indication',
#   'donc',
#   'Ã',
#   '§',
#   'a',
#   'sera',
#   'bien',
#   'fait',
#   'pour',
#   'ma',
#   'gueule',
#   'si',
#   'je',
#   'crÃ',
#   '¨',
#   've',
#   '?',
#   '?',
#   '?',
#   'punaise',
#   'faites',
#   'attention',
#   'Ã',
#   'vos',
#   'mots',
#   'vaccinÃ',
#   '©',
#   's',
#   'Ã',
#   'la',
#   'noi'],
#  ['Paradise',
#   'Lost',
#   '-',
#   "L'exploration",
#   'du',
#   'bunker',
#   'vous',
#   'attend',
#   'cette',
#   'semaine',
#   'sur',
#   'Nintendo',
#   'Switch',
#   'https://t.co/GesRVsGynM',
#   '#NintendoSwitch',
#   'https://t.co/0tyV1ASqOc'],
#  ['@R0quotes',
#   '@requin0501',
#   '@f_philippot',
#   'Il',
#   'est',
#   'con',
#   'LiÃ',
#   '§',
#   'a',
#   '.',
#   ':',
#   'un',
#   'vrai',
#   'nazi',
#   'en',
#   'marche'],
#  ['Je',
#   'ne',
#   'pourrai',
#   'vraiment',
#   'pas',
#   'supporter',
#   'quâ',
#   '\x80',
#   '\x99',
#   'une',
#   'meuf',
#   'avec',
#   'qui',
#   'jâ',
#   '\x80',
#   '\x99',
#   'ai',
#   'parlÃ',
#   '©',
#   'soit',
#   'heureux',
#   'avec',
#   'un',
#   'autre',
#   'negro',
#   'que',
#   'moi',
#   'https://t.co/phzzy4RF35'],
#  ['Ã',
#   '§',
#   'a',
#   'fait',
#   'une',
#   'heure',
#   'que',
#   'je',
#   'pleure',
#   'non',
#   'stop',
#   'je',
#   'suis',
#   'crevÃ',
#   '©',
#   'genre',
#   'jsp',
#   'laissez',
#   'moi',
#   'Ãªtre',
#   'stable',
#   ',',
#   'aller',
#   'en',
#   'cours',
#   ',',
#   'sortir',
#   ',',
#   'voir',
#   'des',
#   'gens',
#   ',',
#   'rÃ',
#   '©',
#   'ussir',
#   'ma',
#   'scolaritÃ',
#   '©',
#   'genre',
#   'non',
#   "j'arrive",
#   'mÃªme',
#   'pas',
#   'Ã',
#   'sortir',
#   'de',
#   'ma',
#   'chambre'],
#  ['Pour',
#   'lâ',
#   '\x80',
#   '\x99',
#   'Obs',
#   ',',
#   'Beethoven',
#   'Ã',
#   '©',
#   'tait',
#   'nazi',
#   '.',
#   'https://t.co/XJfKxH576v'],
#  ['@Braets8',
#   '@f_philippot',
#   'Un',
#   'Diafoirus',
#   'doublÃ',
#   '©',
#   'dâ',
#   '\x80',
#   '\x99',
#   'un',
#   'nazi',
#   '!'],
#  ['@lexza69',
#   '@lucspth_r',
#   'Je',
#   'crÃ',
#   '¨',
#   've',
#   'avec',
#   'toi',
#   'sâ',
#   '\x80',
#   '\x99',
#   'il',
#   'la',
#   'met',
#   ',',
#   'avec',
#   'ses',
#   'Balenciaga',
#   'Ã',
#   '§',
#   'a',
#   'va',
#   'mettre',
#   'un',
#   'pointu',
#   'claquÃ',
#   '©'],
#  ['"',
#   'Bien',
#   'dit',
#   '!',
#   '!',
#   '!',
#   'Personne',
#   "n'est",
#   'dupe',
#   'ZÃ',
#   '©',
#   'ro',
#   'prend',
#   'les',
#   'ð',
#   '\x9f',
#   '\x87',
#   '«',
#   'ð',
#   '\x9f',
#   '\x87',
#   '·',
#   'pour',
#   'des',
#   'andouilles',
#   ',',
#   'il',
#   'voudrait',
#   "qu'on",
#   'oublie',
#   'tout',
#   'ce',
#   "qu'il",
#   'a',
#   'Ã',
#   '©',
#   'crit',
#   ',',
#   'dit',
#   'ou',
#   'fait',
#   'juste',
#   'pcq',
#   "qu'il",
#   "s'est",
#   'autoproclamÃ',
#   '©',
#   'candidat',
#   'aux',
#   'prÃ',
#   '©',
#   'sidentielles'],
#  ['@Proto77037066',
#   '@Sliiim974',
#   '@WJoumarin1',
#   '@ZemmourEric',
#   'Oui',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'Ã',
#   '§',
#   'a',
#   ',',
#   'quand',
#   'ton',
#   'seul',
#   'argument',
#   'câ',
#   '\x80',
#   '\x99',
#   'est',
#   'la',
#   'comparaison',
#   'avec',
#   'Hitler',
#   'Ã',
#   '§',
#   'a',
#   'sâ',
#   '\x80',
#   '\x99',
#   'appelle',
#   'un',
#   'point',
#   'Godwin',
#   ',',
#   'si',
#   'vous',
#   'nâ',
#   '\x80',
#   '\x99',
#   'aimez',
#   'pas',
#   'la',
#   'France',
#   'libre',
#   'Ã',
#   'vous',
#   'de',
#   'la',
#   'quitter',
#   'Ã',
#   '§',
#   'a',
#   'nous',
#   'fera',
#   'des',
#   'vacances'],
#  ['HAHAHAHA',
#   'LE',
#   'PELO',
#   'DES',
#   '12',
#   'COUPS',
#   'DE',
#   'MIDI',
#   'A',
#   'FAIS',
#   'UN',
#   'SALUT',
#   'NAZI',
#   '?',
#   '?',
#   '?'],
#  ['@BeatriceGamba',
#   '@nicolasberrod',
#   "C'est",
#   "d'ailleurs",
#   'ton',
#   'principal',
#   'argument',
#   ':',
#   'le',
#   'COVID',
#   'ne',
#   'crÃ',
#   '¨',
#   've',
#   'que',
#   'les',
#   'handis',
#   ',',
#   'fragiles',
#   ',',
#   'vieux',
#   ',',
#   'donc',
#   'tu',
#   'vois',
#   'pas',
#   'pourquoi',
#   'il',
#   'faudrait',
#   'empÃªcher',
#   'la',
#   'circulation',
#   '.'],
#  ['"',
#   'ð',
#   '\x9f',
#   '¤',
#   '\x94',
#   'ð',
#   '\x9f',
#   '¤',
#   '\x94',
#   'ð',
#   '\x9f',
#   '¤',
#   '\x94',
#   'Propos',
#   "d'internaute",
#   'Klein',
#   ':',
#   "J'ai",
#   '82',
#   'ans',
#   '.',
#   "J'ai",
#   ',',
#   'un',
#   'peu',
#   'vÃ',
#   '©',
#   'cu',
#   'la',
#   '2Ã',
#   '¨',
#   'me',
#   'guerre',
#   '.'],
#  ['moi',
#   'cet',
#   'annÃ',
#   '©',
#   'e',
#   'jâ',
#   '\x80',
#   '\x99',
#   'ai',
#   'crevÃ',
#   '©',
#   '3',
#   'fois',
#   'https://t.co/lxjsw2K0XC'],
#  ['Rita',
#   'Renoir',
#   ',',
#   '@RitaRenoir',
#   ',',
#   'CrÃ',
#   '¨',
#   've-cÅ',
#   '\x93',
#   'ur',
#   '.',
#   'Gif',
#   ':',
#   '@PamelaChougne2',
#   'https://t.co/2HZsPKTJcc'],
#  ['@ENPRESSIONFC',
#   '@AllanDr_',
#   'le',
#   'rapport',
#   'entre',
#   'hitler',
#   'et',
#   'le',
#   'Bayern',
#   'gors',
#   '?',
#   '?'],
#  ['"',
#   "d'accord",
#   'si',
#   "c'est",
#   'pour',
#   'le',
#   '#serpent',
#   'Ã',
#   'Adolf',
#   'Hitler',
#   'en',
#   '#Argentine',
#   'ð',
#   '\x9f',
#   '\x94',
#   '¶',
#   'â',
#   '\x98',
#   '\x9d'],
#  ['@Mister_Misandry',
#   '@nicolasberrod',
#   'Câ',
#   '\x80',
#   '\x99',
#   'est',
#   'Ã',
#   '§',
#   'a',
#   ',',
#   'je',
#   'suis',
#   'Hitler',
#   '.',
#   'Tu',
#   'pars',
#   'en',
#   'live',
#   'un',
#   'peu',
#   'lÃ',
#   'quand',
#   'mÃªme',
#   'non',
#   '?'],
#  ['Ma',
#   'prof',
#   "d'histoire",
#   'qui',
#   'compare',
#   'Ã',
#   'demi-mot',
#   'Zemmour',
#   'et',
#   'Hitler',
#   '...'],
#  ['@NolwennJuno',
#   '@Bunker_D_',
#   'Donc',
#   'pas',
#   "d'insulte",
#   'de',
#   'votre',
#   'part',
#   ',',
#   'mais',
#   'vous',
#   'me',
#   'dites',
#   'que',
#   'je',
#   'suis',
#   'bÃªte',
#   'parce',
#   'que',
#   'je',
#   'qualifie',
#   'vos',
#   'propos',
#   'transphobes',
#   'de',
#   'transphobes',
#   '.',
#   'Allez',
#   "j'ai",
#   'perdu',
#   'trop',
#   'de',
#   'temps',
#   'avec',
#   'un',
#   'troll',
#   "d'extrÃªme",
#   'droite',
#   '.',
#   'Un',
#   'petit',
#   'conseil',
#   ':',
#   'si',
#   'vous',
#   'ne',
#   'voule'],
#  ['"', 'LÃ', '©', 'on', 'Degrelle', ',', 'le', 'nazi', 'belge'],
#  ['"',
#   'Jour',
#   '2',
#   ':',
#   'Westside',
#   'Gunn',
#   '"',
#   '"',
#   'Hitler',
#   'Wears',
#   'Hermes',
#   '8',
#   ':',
#   'Side',
#   'B',
#   '"',
#   '"'],
#  ['"',
#   '@ECiotti',
#   'On',
#   'fait',
#   'quoi',
#   'pour',
#   'les',
#   'Ã',
#   '©',
#   'tudiants',
#   'qui',
#   'crÃ',
#   '¨',
#   've',
#   'la',
#   'fin',
#   'les',
#   'gens',
#   'qui',
#   'vont',
#   'au',
#   'restau',
#   'du',
#   'cÅ',
#   '\x93',
#   'ur',
#   'le',
#   '15',
#   'du',
#   'mois',
#   'mais',
#   'une',
#   'femme',
#   'musulman',
#   'qui',
#   'porte',
#   'un',
#   'voile',
#   'reste',
#   'plus',
#   'important',
#   'a',
#   'dÃ',
#   '©',
#   'battre'],
#  ['je', 'crÃ', '¨', 've', 'https://t.co/0FviORlXkG'],
#  ['Js', 'un', 'noich', 'depuis', 'octobre'],
#  ['Ma',
#   'soeur',
#   'qui',
#   'craque',
#   'quand',
#   'je',
#   'lui',
#   'raconte',
#   'mes',
#   'nuits',
#   'de',
#   'bamboula',
#   'jusquâ',
#   '\x80',
#   '\x99',
#   'Ã',
#   '4h',
#   'du',
#   'mat',
#   'et',
#   'quâ',
#   '\x80',
#   '\x99',
#   'elle',
#   'me',
#   'raconte',
#   'ses',
#   'nuits',
#   'de',
#   'bamboula',
#   'dans',
#   'le',
#   'vomi',
#   'de',
#   'son',
#   'fils',
#   'https://t.co/11hSrEuOvm'],
#  ['@TCQNVP',
#   '@Midilibre',
#   'Ce',
#   'nazi',
#   'Ã',
#   '§',
#   'a',
#   'lui',
#   'correspond',
#   'mieux',
#   'ð',
#   '\x9f',
#   '\x98',
#   '\x89'],
#  ['"',
#   '@jean__massena',
#   '"',
#   '"',
#   'Si',
#   'tu',
#   'es',
#   'contre',
#   "l'immigration",
#   ':',
#   'Tu',
#   'es',
#   'raciste',
#   'et',
#   'presque',
#   'nazi',
#   ',',
#   'fin',
#   'du',
#   'dÃ',
#   '©',
#   'bat',
#   '.',
#   '"',
#   '"'],
#  ['mais',
#   'Ã',
#   '§',
#   'a',
#   'marche',
#   'pas',
#   'Ã',
#   '§',
#   'a',
#   'hein',
#   'fin',
#   'on',
#   'peut',
#   'pas',
#   'dire',
#   'Ã',
#   '§',
#   'a',
#   'pour',
#   'hitler',
#   'pour',
#   'la',
#   'pÃ',
#   '©',
#   'riode',
#   '39',
#   '45',
#   'quoi',
#   'https://t.co/HuNc6ZbjbB'],
#  ['Je',
#   'comprends',
#   'que',
#   'nous',
#   'avons',
#   'remplacer',
#   'une',
#   'pandÃ',
#   '©',
#   'mie',
#   'par',
#   'une',
#   'idÃ',
#   '©',
#   'ologie',
#   'des',
#   'vaccinÃ',
#   '©',
#   's',
#   'contre',
#   'les',
#   'non-vaccinÃ',
#   '©',
#   's',
#   '...',
#   'Il',
#   'y',
#   'a',
#   'des',
#   'livres',
#   "qu'il",
#   'faudrait',
#   'relire',
#   '...',
#   'Ã',
#   '©',
#   'crit',
#   'pas',
#   'un',
#   'certain',
#   'hitler',
#   '...'],
#  ['@LP_LaPresse',
#   'Qui',
#   'crÃ',
#   '¨',
#   've',
#   'en',
#   'prison',
#   'le',
#   'sale',
#   ',',
#   'ils',
#   'ont',
#   'assez',
#   'fait',
#   'dâ',
#   '\x80',
#   '\x99',
#   'harcÃ',
#   '¨',
#   'lement',
#   'contre',
#   'les',
#   'gens',
#   ',',
#   'dont',
#   'moi',
#   'ð',
#   '\x9f',
#   '\x98',
#   '¤',
#   'ð',
#   '\x9f',
#   '\x98',
#   '¤',
#   'ð',
#   '\x9f',
#   '\x98',
#   '¤',
#   'ð',
#   '\x9f',
#   '\x98',
#   '¤',
#   'ð',
#   '\x9f',
#   '\x98',
#   '¤'],
#  ['@lauhaim',
#   'Ceux',
#   'qui',
#   'votent',
#   'pour',
#   'Zemmour',
#   'ne',
#   'sont',
#   'non',
#   'seulement',
#   'ridicules',
#   'mais',
#   'aussi',
#   'racistes',
#   ',',
#   'on',
#   'va',
#   'quand',
#   'mÃªme',
#   'pas',
#   'commencer',
#   'Ã',
#   'dire',
#   'quâ',
#   '\x80',
#   '\x99',
#   'ils',
#   'ont',
#   'le',
#   'droit',
#   'dâ',
#   '\x80',
#   '\x99',
#   'Ãªtre',
#   'raciste',
#   ',',
#   'souvenez-vous',
#   'en',
#   '1900',
#   'et',
#   'dÃ',
#   '©',
#   'poussiÃ',
#   '¨',
#   're',
#   'Hitler',
#   'est',
#   'arrivÃ',
#   '©',
#   'par',
#   'les',
#   'urnes',
#   'au',
#   'pouvoir'],
#  ['"',
#   '@malopedia',
#   'Le',
#   'fascisme',
#   'est',
#   'trÃ',
#   '¨',
#   's',
#   'particulier',
#   'et',
#   'zemmour',
#   "n'est",
#   'ni',
#   'fasciste',
#   ',',
#   'ni',
#   'nazi',
#   ',',
#   'ni',
#   'franquiste',
#   ',',
#   'ni',
#   'communiste',
#   ',',
#   'ni',
#   'totalitariste',
#   'dans',
#   'sa',
#   'dÃ',
#   '©',
#   'finition',
#   'arendtienne',
#   '.'],
#  ...]

# %%
# PROCESS DATA E.G. CLEANING

# %%
df['tokenized_tweet'] = df['tokenized_tweet'].astype(str)

# %%
X = df['tokenized_tweet'] # list of tokenized tweets
y = df['label'] # list of labels of tweets

# %%
# split X and y into training and testing sets
# randomizes data in splitting
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
# indicating random state ensures data split will be same
#https://stackoverflow.com/questions/28064634/random-state-pseudo-random-number-in-scikit-learn

# %%
# check the shape of X_train and X_test

X_train.shape, X_test.shape
# ((2284, 10), (572, 10))
# Out:
# ((2284,), (572,))

# %%
y_train.shape, y_test.shape
# ((2284,), (572,))
# Out:
# ((2284,), (572,))

# %%
# check data types in X_train

X_train.dtypes
# Out:
# dtype('O')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# can't run LR or MNB (models) until vectorize (or bow)

# Initialize our vectorizer (featurizer, turning text to numbers)
#only looking at numbers produced, creating features
# takes each tweet turning into feature vector, each column corresponds to word
vectorizer = TfidfVectorizer() # empty model

# fit vectorizer w/ train data (training data)
# This makes your vocab matrix, learns words in vocab
vectorizer.fit(X_train)

# This transforms your documents into vectors (numbers).
X_train = vectorizer.transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
# function to test and evaluate models. 
from sklearn import metrics
# For plotting
import matplotlib.pyplot as plt

def build_and_eval_model_old(model, X, y, random_state=23):
    print("Running report for model:", model)

#     X_train, X_test, y_train, y_test = train_test_split(
#         X, y, test_size=0.20, random_state=random_state)    
    
    # Fit our model.
    model.fit(X_train, y_train)
    
    # Get the accuracy
    accuracy = model.score(X_test, y_test)
    print("\n\nAccuracy %f" % accuracy)
    
    
    # Make new predictions
    y_pred = model.predict(X_test)
    
    
    # Print the classification report. 
    print(metrics.classification_report(y_test, y_pred))
    
        
    # Plot the confusion matrix
    fig, ax = plt.subplots(figsize=(13,13))
    
    metrics.plot_confusion_matrix(estimator=model, 
                                  X=X_test, 
                                  y_true=y_test, 
                                  ax=ax)

    # Return the fitted model. 
    return model

# %%
# function to test and evaluate models. 
from sklearn import metrics
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix

# For plotting
import matplotlib.pyplot as plt

def build_and_eval_model(model, X, y):
    print("Running report for model:", model) 
    
    # Fit our model.
    model.fit(X_train, y_train)
    
    
    # predicting results based on testing data
    y_pred = model.predict(X_test)
    # Make predicted probabilites of our testing data
#     y_pred_proba = model.predict_proba(X_test)
# https://stackoverflow.com/questions/15111408/how-does-sklearn-svm-svcs-function-predict-proba-work-internally

    # Get the evaluation metrics
    accuracy = model.score(X_test, y_test)
    print("\n\nAccuracy %f" % accuracy)
    
    print('Model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
    # y_test are true class labels and y_pred are predicted class labels in test-set
    
    # f1-score is always lower than accuracy measures, they embed precision and recall into their computation
#     print('F1 Score: %.4f' % f1_score(y_test, y_pred, pos_label='0'))
    # https://datascience.stackexchange.com/questions/54436/valueerror-pos-label-1-is-not-a-valid-label-arrayn-y-dtype-u1
    f1score = f1_score(y_test, y_pred, average='macro')
    print('macro F-1 score : {}'.format(np.round(f1score,5)))
    # macro avg f1score = unweighted mean of all the per-class F1 scores, treats all classes equally important
    # weighted-averaged F1 score is calculated by taking the mean of all per-class F1 scores while considering each class’s support
    ## ‘weight’ refers to proportion of each class’s support relative to the sum of all support values
    # https://towardsdatascience.com/micro-macro-weighted-averages-of-f1-score-clearly-explained-b603420b292f
    
    # compare the train-set and test-set accuracy to check for overfitting
    y_pred_train = model.predict(X_train)
    print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
    # print the accuracy scores on training and test set
    print('Training accuracy set score: {:.4f}'.format(model.score(X_train, y_train)))
    
    print('Test set accuracy score: {:.4f}'.format(model.score(X_test, y_test)))

    # Print the classification report. 
    print(metrics.classification_report(y_test, y_pred))
    
        
    # Plot the confusion matrix
    fig, ax = plt.subplots(figsize=(13,13))
    
    metrics.plot_confusion_matrix(estimator=model, 
                                  X=X_test, 
                                  y_true=y_test, 
                                  ax=ax)
    
    cm = confusion_matrix(y_test, y_pred)
    print('Confusion matrix\n\n', cm)
    print('\nTrue Positives(TP) = ', cm[0,0])
    print('\nTrue Negatives(TN) = ', cm[1,1])
    print('\nFalse Positives(FP) = ', cm[0,1])
    print('\nFalse Negatives(FN) = ', cm[1,0])

#     # visualize confusion matrix with seaborn heatmap
#     cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], 
#                                  index=['Predict Positive:1', 'Predict Negative:0'])
#     sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
    
    
    # print classification accuracy, same as test set score & model accuracy score
    classification_accuracy = (cm[0,0] + cm[1,1]) / float(cm[0,0] + cm[1,1] + cm[0,1] + cm[1,0])
    print('Classification accuracy : {0:0.4f}'.format(classification_accuracy))
    
    # print classification error
    classification_error = (cm[0,1] + cm[1,0]) / float(cm[0,0] + cm[1,1] + cm[0,1] + cm[1,0])
    print('Classification error : {0:0.4f}'.format(classification_error))

    # Return the fitted model. 
    return model

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
build_and_eval_model(lr, X, y)
# Out:
# Running report for model: LogisticRegression()
#
#
# Accuracy 0.753497
# Model accuracy score: 0.7535
# macro F-1 score : 0.66742
# Training-set accuracy score: 0.8595
# Training set score: 0.8595
# Test set accuracy score: 0.7535
#               precision    recall  f1-score   support
#
#            0       0.76      0.93      0.84       390
#            1       0.71      0.38      0.50       182
#
#     accuracy                           0.75       572
#    macro avg       0.74      0.66      0.67       572
# weighted avg       0.75      0.75      0.73       572
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mc/1k6qg5js1x31mqzdq17v2yym0000gn/T/ipykernel_54078/1443839457.py in <module>
#       2
#       3 lr = LogisticRegression()
# ----> 4 build_and_eval_model(lr, X, y)
#
# /var/folders/mc/1k6qg5js1x31mqzdq17v2yym0000gn/T/ipykernel_54078/2132816060.py in build_and_eval_model(model, X, y)
#      58                                   ax=ax)
#      59
# ---> 60     cm = confusion_matrix(y_test, y_pred)
#      61     print('Confusion matrix\n\n', cm)
#      62     print('\nTrue Positives(TP) = ', cm[0,0])
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn import svm

lsvc = svm.LinearSVC()
build_and_eval_model(lsvc, X, y)
# Out:
# Running report for model: LinearSVC()
#
#
# Accuracy 0.793706
# Model accuracy score: 0.7937
# macro F-1 score : 0.75634
# Training-set accuracy score: 0.9974
# Training set score: 0.9974
# Test set accuracy score: 0.7937
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       390
#            1       0.69      0.63      0.66       182
#
#     accuracy                           0.79       572
#    macro avg       0.76      0.75      0.76       572
# weighted avg       0.79      0.79      0.79       572
#
# Confusion matrix
#
#  [[339  51]
#  [ 67 115]]
#
# True Positives(TP) =  339
#
# True Negatives(TN) =  115
#
# False Positives(FP) =  51
#
# False Negatives(FN) =  67
# Classification accuracy : 0.7937
# Classification error : 0.2063
# LinearSVC()

# %%
mnb = MultinomialNB(alpha=.05)

# run classifier using 10-fold cross validation
# runs cross validation on dataset to test whether model can generalise over whole dataset
# function returns list of one score per split, and average of scores can be calculated to provide a single metric value for dataset
# MNB_scores = cross_val_score(mnb, X, y, scoring='accuracy', cv=10)
# print(MNB_scores.mean())

build_and_eval_model(mnb, X, y)
# Out:
# Running report for model: MultinomialNB(alpha=0.05)
#
#
# Accuracy 0.748252
# Model accuracy score: 0.7483
# macro F-1 score : 0.66742
# Training-set accuracy score: 0.9943
# Training set score: 0.9943
# Test set accuracy score: 0.7483
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.83       390
#            1       0.68      0.40      0.50       182
#
#     accuracy                           0.75       572
#    macro avg       0.72      0.66      0.67       572
# weighted avg       0.74      0.75      0.73       572
#
# Confusion matrix
#
#  [[355  35]
#  [109  73]]
#
# True Positives(TP) =  355
#
# True Negatives(TN) =  73
#
# False Positives(FP) =  35
#
# False Negatives(FN) =  109
# Classification accuracy : 0.7483
# Classification error : 0.2517
# MultinomialNB(alpha=0.05)

# %%
svc = svm.SVC()
build_and_eval_model(svc, X, y)
# Out:
# Running report for model: SVC()
#
#
# Accuracy 0.765734
# Model accuracy score: 0.7657
# macro F-1 score : 0.68909
# Training-set accuracy score: 0.9921
# Training set score: 0.9921
# Test set accuracy score: 0.7657
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84       390
#            1       0.73      0.42      0.53       182
#
#     accuracy                           0.77       572
#    macro avg       0.75      0.67      0.69       572
# weighted avg       0.76      0.77      0.75       572
#
# Confusion matrix
#
#  [[361  29]
#  [105  77]]
#
# True Positives(TP) =  361
#
# True Negatives(TN) =  77
#
# False Positives(FP) =  29
#
# False Negatives(FN) =  105
# Classification accuracy : 0.7657
# Classification error : 0.2343
# SVC()

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

build_and_eval_model(rf, X, y)
# Out:
# Running report for model: RandomForestClassifier()
#
#
# Accuracy 0.767483
# Model accuracy score: 0.7675
# macro F-1 score : 0.69212
# Training-set accuracy score: 0.9996
# Training set score: 0.9996
# Test set accuracy score: 0.7675
#               precision    recall  f1-score   support
#
#            0       0.78      0.93      0.84       390
#            1       0.73      0.43      0.54       182
#
#     accuracy                           0.77       572
#    macro avg       0.75      0.68      0.69       572
# weighted avg       0.76      0.77      0.75       572
#
# Confusion matrix
#
#  [[361  29]
#  [104  78]]
#
# True Positives(TP) =  361
#
# True Negatives(TN) =  78
#
# False Positives(FP) =  29
#
# False Negatives(FN) =  104
# Classification accuracy : 0.7675
# Classification error : 0.2325
# RandomForestClassifier()

# %%
#  a Wilcoxon test, as Vanetik and Mimoun 2022 do, to find the p-value,

# %%
# run classifier using 10-fold cross validation
# runs cross validation on dataset to test whether model can generalise over whole dataset
# function returns list of one score per split, and average of scores can be calculated to provide a single metric value for dataset
MNB_scores = cross_val_score(MultinomialNB(), X, y, scoring='accuracy', cv=10)
print(MNB_scores.mean())
# Out:
# nan
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 612, in fit
#     X, y = self._check_X_y(X, y)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 477, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 673, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 857, in __array__
#     return np.asarray(self._values, dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/numpy_.py", line 131, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: '"Je ne vous partage pas Ã§a pour vous rappeler que les boomers qui se disent ""rÃ©publicains"" sont en train de saliver Ã\xa0 l\'idÃ©e de savoir avec quelle fragrance d\'Hitler ils se parfumeront au printemps. Non, juste vous rappeler ce que valent les sondages dont on nous assomme. https://t.co/lU2rRfMeKf"'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 612, in fit
#     X, y = self._check_X_y(X, y)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 477, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 673, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 857, in __array__
#     return np.asarray(self._values, dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/numpy_.py", line 131, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Elle ne devait pas dÃ©gager la nazi ??? https://t.co/NAGVyrhsXy'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 612, in fit
#     X, y = self._check_X_y(X, y)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 477, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 673, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 857, in __array__
#     return np.asarray(self._values, dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/numpy_.py", line 131, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Elle ne devait pas dÃ©gager la nazi ??? https://t.co/NAGVyrhsXy'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 612, in fit
#     X, y = self._check_X_y(X, y)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 477, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 673, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 857, in __array__
#     return np.asarray(self._values, dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/numpy_.py", line 131, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Elle ne devait pas dÃ©gager la nazi ??? https://t.co/NAGVyrhsXy'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 612, in fit
#     X, y = self._check_X_y(X, y)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 477, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 673, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 857, in __array__
#     return np.asarray(self._values, dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/numpy_.py", line 131, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Elle ne devait pas dÃ©gager la nazi ??? https://t.co/NAGVyrhsXy'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 612, in fit
#     X, y = self._check_X_y(X, y)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 477, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 673, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 857, in __array__
#     return np.asarray(self._values, dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/numpy_.py", line 131, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Elle ne devait pas dÃ©gager la nazi ??? https://t.co/NAGVyrhsXy'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 612, in fit
#     X, y = self._check_X_y(X, y)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 477, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 673, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 857, in __array__
#     return np.asarray(self._values, dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/numpy_.py", line 131, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Elle ne devait pas dÃ©gager la nazi ??? https://t.co/NAGVyrhsXy'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 612, in fit
#     X, y = self._check_X_y(X, y)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 477, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 673, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 857, in __array__
#     return np.asarray(self._values, dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/numpy_.py", line 131, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Elle ne devait pas dÃ©gager la nazi ??? https://t.co/NAGVyrhsXy'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 612, in fit
#     X, y = self._check_X_y(X, y)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 477, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 673, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 857, in __array__
#     return np.asarray(self._values, dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/numpy_.py", line 131, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Elle ne devait pas dÃ©gager la nazi ??? https://t.co/NAGVyrhsXy'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 612, in fit
#     X, y = self._check_X_y(X, y)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/naive_bayes.py", line 477, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 673, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py", line 857, in __array__
#     return np.asarray(self._values, dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/numpy_.py", line 131, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py", line 102, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Elle ne devait pas dÃ©gager la nazi ??? https://t.co/NAGVyrhsXy'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], 
                                 index=['Predict Positive:1', 'Predict Negative:0'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <AxesSubplot:>
